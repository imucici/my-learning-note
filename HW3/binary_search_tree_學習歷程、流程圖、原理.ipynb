# %% [markdown]
# 11/8開始研究BST，上網看了BST的概念，最初步的理解是當新插入的節點比root大，要放到右邊(right child)，比root小，要放到左邊(left child)，另外BST有新增、刪除、修改、查詢等功能。
#
# 參考資料:
#
# 1. http://alrightchiu.github.io/SecondRound/binary-search-tree-introjian-jie.html
#
# 2. http://alrightchiu.github.io/SecondRound/binary-search-tree-searchsou-xun-zi-liao-insertxin-zeng-zi-liao.html
#
# 3. http://alrightchiu.github.io/SecondRound/binary-search-tree-sortpai-xu-deleteshan-chu-zi-liao.html
#
# 4. https://www.itread01.com/content/1545296408.html
#
#
# 花了2天看懂網路上的參考資料，11/10開始嘗試寫code:
#
# 因為老師說BST的概念跟LinkedList很像，因此我在建BST之前，先複習了當初Linked List的程式碼，之後仿照建LinkedList的概念建BST:
#
# class Node:
#
#     def __init__ (self,val):
#         self.val = val
#         self.next = None
#
# > 因為每個節點包含一個val和指向下一個節點的next字段，因此在創建Node這個class時，要先初始化它的值 = val，next字段指向"空"
#
#
# class MyLinkedList:
#
#     def __init__(self):
#
#         self.head = None
#         self.size = 0
#
# > 初始化節點後，再接著初始化整個鍊表為空。

# %% [markdown]
# insert

# %%
# 初始化每個 Node包含 val和 leftChild、RightChild，這樣之後每新增一個Node時都能包含val、left、right

class Node:
    
    def __init__ (self,val):
        self.val = val 
        self.left = None
        self.right = None         

class BST:

#初始化BST為空(root不存在、長度=0)

    def __init__(self):
       
        self.root = None 
        
        
    def insert(self,val):
        
        newinsert = Node(val)
        
        if self.root == None: 
            self.root = newinsert
            
        
        if newinsert == self.val :
            return False
        
        elif newinsert > self.root: # 會被放到右邊
            if self.right == None :
                
                return True
            else:
                while self.right != None:
                    self.root = self.right
                
                return True
        else: # 會被放到左邊
            if self.left == None :
                
                return True
            else:
                while self.left != None:
                    self.root = self.left
                
                return True

# %%
a = BST()

# %%
a.insert(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-a4df7e4b445f> in <module>
# ----> 1 a.insert(10)
#
# <ipython-input-1-10ccf03bf0ee> in insert(self, val)
#      25
#      26
# ---> 27         if newinsert == self.val :
#      28             return False
#      29
#
# AttributeError: 'BST' object has no attribute 'val'

# %% [markdown]
# 嗯...錯誤訊息的意思是 因為沒有事先定義val，因此在第27行找不到"val"這個屬性，當tree裡面不存在任何值時，新增進去的那個節點會呼叫Node來賦予它val、left、right這些屬性，但是假如tree裡面已經事先存在節點時，那些節點勢必已被賦予那三個屬性，因此我將tree用"if"、"else"分為兩種狀況，"tree為空"、"tree本來就有值存在"
#
#
# 運行看看語法有沒有錯誤~

# %%
# 初始化每個 Node包含 val和 leftChild、RightChild，這樣之後每新增一個Node時都能包含val、left、right

class Node:
    
    def __init__ (self,val):
        self.val = val 
        self.left = None
        self.right = None         

class BST:

#初始化BST為空(root不存在、長度=0)

    def __init__(self):
       
        self.root = None 
        
    def insert(self,val):
        
#         self.val = val
        
        newinsert = Node(val)
        
        if self.root == None: 
            self.root = newinsert
            
        #因為tree裡面已經有節點，所以照理說root就已經有val、left、right這些屬性
        
        else:
            
            if newinsert == self.val :
                return False

            elif newinsert > self.root: # 會被放到右邊
                if self.right == None :
                    
                    return True
                else:
                    while self.right != None:
                        self.root = self.right
                    
                    return True
            else: # 會被放到左邊
                if self.left == None :
                    
                    return True
                else:
                    while self.left != None:
                        self.root = self.left
                    
                    return True

# %% [markdown]
# 語法感覺沒錯，接著新增值進去測試邏輯有沒有錯

# %%
a = BST()

# %%
a.insert(10)

# %% [markdown]
# 咦?沒return任何訊息，再檢查哪裡寫錯了
#
# 我猜測會不會是因為遞迴時每次都會再初始化一次，因此我想說再外面額外創一個def來協助處理，看看能否每次遞迴時都避掉重新初始化

# %%
class Node:
    
    def __init__ (self,val):
        self.val = val 
        self.left = None
        self.right = None
        
    def insert_Helper(self,val):
        if self.val == val:
            return False

        elif val > self.val: # 會被放到右邊
            if self.right == None :
                self.right = Node(val)
                return True
            else:
                return self.right.insert_Helper(val)
        
        else: # 會被放到左邊
            if self.left == None :
                self.left = Node(val)
                return True
            else:
                return self.left.insert_Helper(val)
        
class BST:

#初始化BST為空(root不存在、長度=0)

    def __init__(self):
       
        self.root = None 
        
    def insert(self,val):
        
        if self.root == None: 
            self.root = Node(val)
            return True
        
        # else情況 self.size不等於0
        else:
            return self.root.insert_Helper(val)

# %%
a = BST()

# %%
a.insert(10)
# Out:
# True

# %%
a.insert(10)
# Out:
# False

# %% [markdown]
# 太好了，這個方法行的通

# %% [markdown]
# insert完成!接著寫search

# %%
class Node:
    
    def __init__ (self,val):
        self.val = val 
        self.left = None
        self.right = None
        
    def insert_Helper(self,val):
        if self.val == val:
            return False

        elif val > self.val: # 會被放到右邊
            if self.right == None :
                self.right = Node(val)
                return True
            else:
                return self.right.insert_Helper(val)
        
        else: # 會被放到左邊
            if self.left == None :
                self.left = Node(val)
                return True
            else:
                return self.left.insert_Helper(val)
        
class BST:

#初始化BST為空(root不存在、長度=0)

    def __init__(self):
       
        self.root = None 
        
    def insert(self,val):
        
        if self.root == None: 
            self.root = Node(val)
            return True
        
        # else情況 self.size不等於0
        else:
            return self.root.insert_Helper(val)
        
    def search(self,val):
        
        self.val = val
        #存在
        if val == self.val:
            return True
        if self.root == None:
            return False

        elif val > self.val:
            return self.right.find(val)
        
        else:
            return self.left.find(val)

# %%
a = BST()
a.insert(10)
a.insert(20)
a.insert(5)
a.search(9)
# Out:
# True

# %% [markdown]
# 搜尋一個不存在的值，竟然return True @@ ，重新釐清程式碼有哪裡寫錯>>>把思路寫起來，順便畫個圖方便理解。
#
# >舉例畫出tree後，發現少考慮到當val不等於當前所處位置的值時，還會有兩種情況發生:"孩子節點不存在，代表整個tree搜尋結束，此值不存在"、"還未搜尋完，繼續遞迴"

# %%
class Node:
    
    def __init__ (self,val):
        self.val = val 
        self.left = None
        self.right = None
        
    def insert_Helper(self,val):
        if self.val == val:
            return False

        elif val > self.val: # 會被放到右邊
            if self.right == None :
                self.right = Node(val)
                return True
            else:
                return self.right.insert_Helper(val)
        
        else: # 會被放到左邊
            if self.left == None :
                self.left = Node(val)
                return True
            else:
                return self.left.insert_Helper(val)
        
class BST:

#初始化BST為空(root不存在、長度=0)

    def __init__(self):
       
        self.root = None 
        
    def insert(self,val):
        
        if self.root == None: 
            self.root = Node(val)
            return True
        
        # else情況 self.size不等於0
        else:
            return self.root.insert_Helper(val)
        
    def search(self,val):
        
        self.val = val

        
        if self.root == None:
            return False
        
        if val == self.val:
            return True

        elif val > self.val:
            if self.right == None :
                return False
            else:
                return self.right.find(val)
        
        else:
            if self.left == None:
                return False
            else:
                return self.left.find(val)

# %%
a = BST()
a.insert(10)
a.insert(20)
a.insert(5)
a.search(7)
# Out:
# True

# %% [markdown]
# 奇怪....感覺不像條件漏考慮，猜想應該是在遞迴時出問題

# %%
class Node:
    
    def __init__ (self,val):
        self.val = val 
        self.left = None
        self.right = None
        
    def insert_Helper(self,val):
        if self.val == val:
            return False

        elif val > self.val: # 會被放到右邊
            if self.right == None :
                self.right = Node(val)
                return True
            else:
                return self.right.insert_Helper(val)
        
        else: # 會被放到左邊
            if self.left == None :
                self.left = Node(val)
                return True
            else:
                return self.left.insert_Helper(val)
            
    def find_helper(self,val):
        if val == self.val:
            return True

        elif val > self.val:
            if self.right == None :
                return False
            else:
                return self.right.find_helper(val)
        
        else:
            if self.left == None:
                return False
            else:
                return self.left.find_helper(val)
        
        
        

class BST:

#初始化BST為空(root不存在、長度=0)

    def __init__(self):
       
        self.root = None 
        
    def insert(self,val):
        
        if self.root == None: 
            self.root = Node(val)
            return True
        
        # else情況 self.size不等於0
        else:
            return self.root.insert_Helper(val)
        
    def search(self,val):
              
        if self.root == None:
            return False
        else:
            return self.root.find_helper(val)

# %%
a = BST()
a.insert(1)
a.insert(10)
a.search(10)
a.search(12)
# Out:
# False

# %% [markdown]
# 看起來新增和查詢都沒問題，再繼續寫delete

# %% [markdown]
# 刪除節點實在太難了@@，看了好久始終不知道怎麼打，後來看到網路上有人的寫法大約看得懂，因此稍微研究了一下
#
# > 參考網站: https://github.com/joeyajames/Python/blob/master/Trees/BinarySearchTree.py

# %% [markdown]
# 某次跟同學討論的過程中，發現上面我為了避掉遞迴時重新初始化，額外創了個help函式，可以寫成在外面直接呼叫TreeNode()新增一個節點，在這同時那個新節點就會直接被賦予val、left、right三個屬性，因此我將程式碼做了些修改~

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            if root.left == None:
                root.left = TreeNode(val)
                print("下面沒節點的情況下，將相同的節點加到左邊")
                return True
            else:
                root.left = TreeNode(val)
                TreeNode(val).left = root.left
                print("下面有節點的情況下，將相同的節點加到左邊")
                return True
        
        
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                print("新節點加到左邊")
                return True
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                print("新節點加到右邊")
                return True
            else:
                return Solution().insert(root.right,val)
            
#     def delete(self,root,target):
        
#     def search(self,root,target):
        
#     def modify(self,root,target,new_val):

# %%
a = Solution()
root = TreeNode(10)
a.insert(root,10)
a.insert(root,20)
a.insert(root,20)
a.insert(root,7)
# Out:
# 下面沒節點的情況下，將相同的節點加到左邊
# 新節點加到右邊
# 下面沒節點的情況下，將相同的節點加到左邊
# 新節點加到左邊
# True

# %% [markdown]
# search

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            if root.left == None:
                root.left = TreeNode(val)
                print("下面沒節點的情況下，將相同的節點加到左邊")
                return True
            else:
                root.left = TreeNode(val)
                TreeNode(val).left = root.left
                print("下面有節點的情況下，將相同的節點加到左邊")
                return True
        
        
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                print("新節點加到左邊")
                return True
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                print("新節點加到右邊")
                return True
            else:
                return Solution().insert(root.right,val)
            
#     def delete(self,root,target):
        
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target，就可以return 
        
        if target  == root.val:
            return target
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
        
#     def modify(self,root,target,new_val):

# %%
a = Solution()
root = TreeNode(10)
a.insert(root,10)
a.insert(root,20)
a.insert(root,20)
a.insert(root,7)
a.search(root,7)
a.search(root,15)
a.search(root,10)
# Out:
# 下面沒節點的情況下，將相同的節點加到左邊
# 新節點加到右邊
# 下面沒節點的情況下，將相同的節點加到左邊
# 新節點加到左邊
# 10

# %% [markdown]
# 11/14開始動手寫delete的部分，起初的想法是先找到要刪除的那個目標，之後再往下尋找他的替補值(另外設一個replace函式)

# %%
from IPython.display import Image
from IPython.core.display import HTML
Image(url="https://github.com/imucici/my-learning-note/blob/master/%E5%9C%96%E7%89%87/replace.jpg?raw=true"  ,width = 1000,height = 1000)
# Out:
# <img src="https://github.com/imucici/my-learning-note/blob/master/%E5%9C%96%E7%89%87/replace.jpg?raw=true" width="1000" height="1000"/>

# %% [markdown]
# delete

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            if root.left == None:
                root.left = TreeNode(val)
                print("下面沒節點的情況下，將相同的節點加到左邊")
                return True
            else:
                root.left = TreeNode(val)
                TreeNode(val).left = root.left
                print("下面有節點的情況下，將相同的節點加到左邊")
                return True
        
        
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                print("新節點加到左邊")
                return True
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                print("新節點加到右邊")
                return True
            else:
                return Solution().insert(root.right,val)
            
            
            

#     # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
#     def largestLeft(target):
#         tempL = target.left
#         if target.right == None:
#             while tempL.left != None:
#                 tempL = tempL.left
#             return tempL
        
#     # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
#     def smallestright(target):
#         tempR = target.right
#         if target.left == None or (target.left != None and target.right != None):
#             while tempR.right != None:
#                 tempR = tempR.right
#             return tempR
 
  
    def replace(target):
        if target.right == None: # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
            temp = target.left
            while temp.left != None:
                temp = temp.left
        
        # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
        elif target.left == None : 
            temp = target.right
            while temp.right != None:
                temp = temp.right
        elif target.left != None and target.right != None :
            temp = target.right
            while temp.right != None:
                temp = temp.right
        return temp
            
   
    def pre_order(self,root): # root-->left-->right
        
        preorder = []
        if self.root == None:
            return False
        
        else:
            preorder.append(root.val)
            if self.left != None:
                return Solution().self.left.pre_order(preorder)
            if self.right != None:
                return Solution().self.right.pre_order(preorder)
            
        return preorder
    
            
#     def delete(self,root,target):
        
#        # case1:BST中沒有重複值
#        # 轉成set後長度沒有變動
#         if len(preorder) == len(set(preorder)) :
            
#             old = Solution().search(root,target)
#             new = Solution().replace(target)
            
#             old = new # 將target用替補值取代
#             if new.left != None or new.right != None: 
#                 new_new = Solution().replace(new)
#                 cor = Solution().delete(new_new)
                
#                 new_new = cor
                    
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
        if target  == root.val:
            return target
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
        
#     def modify(self,root,target,new_val):

# %%
a = Solution()
root = TreeNode(10)
a.insert(root,9)
a.insert(root,8)
a.insert(root,7)
a.pre_order(root)
# Out:
# 新節點加到左邊
# 新節點加到左邊
# 新節點加到左邊
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-9e29aee46e5f> in <module>
#       4 a.insert(root,8)
#       5 a.insert(root,7)
# ----> 6 a.pre_order(root)
#
# <ipython-input-35-6b3ffd2adb77> in pre_order(self, root)
#      77
#      78         preorder = []
# ---> 79         if self.root == None:
#      80             return False
#      81
#
# AttributeError: 'Solution' object has no attribute 'root'

# %% [markdown]
# def pre_order(self,root): # root-->left-->right
#
#         preorder = []
#         if self.root == None:
#             return False
#
#         else:
#             preorder.append(root.val)
#             if self.left != None:
#                 return Solution().self.left.pre_order(preorder)
#             if self.right != None:
#                 return Solution().self.right.pre_order(preorder)
#
#         return preorder
#
#
# > 由於在最一開始就已經有賦予root，val、left、right，因此在這個def裡面可以直接使用到這三個屬性，修改完再次執行還是報錯，後來重新看遞迴的部分，要傳入pre_order這個函式的東西應該要是一個node(新一輪的root)

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            if root.left == None:
                root.left = TreeNode(val)
                print("下面沒節點的情況下，將相同的節點加到左邊")
                return True
            else:
                root.left = TreeNode(val)
                TreeNode(val).left = root.left
                print("下面有節點的情況下，將相同的節點加到左邊")
                return True
        
        
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                print("新節點加到左邊")
                return True
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                print("新節點加到右邊")
                return True
            else:
                return Solution().insert(root.right,val)       

 
  
    def replace(root,target): #要怎麼跟search取得找到的那個target，也就是當下的root所在位置
        
        if root.right == None and root.left != None: # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
            temp = root.left
            while temp.right != None:
                temp = temp.right
        
        # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
        elif root.left == None and root.right != None: 
            temp = root.right
            while temp.left != None:
                temp = temp.left
                
        elif root.left != None and root.right != None :
            temp = root.right
            while temp.left != None:
                temp = temp.left
        
        return temp
            
   
    def pre_order(self,root): # root-->left-->right
        
        preorder = [] 
        
        if root == None:
            return False
        
        else:
            preorder.append(root.val)
            print(preorder)
            if root.left != None:
                Solution().pre_order(root.left)
            if root.right != None:
                Solution().pre_order(root.right)
        return preorder
    
            
    def delete(self,root,target):
        
        parent = None
        delete_node = root
        
        #先找到要刪除的那個node
        while target != delete_node.val:
            parent = delete_node
            
            #第一大類:BST中沒有重複值
            if delete_node.left != delete_node.val:
                
                # case1:delete_node沒有任何小孩，直接將delete_node刪除
                if delete_node.left == None and delete_node.right == None:
                    # case1-1:delete_node比parent小，將parent左小孩指向空
                    if delete_node.val < parent.val:
                        parent.left == None
                    # case1-2:delete_node比parent大，將parent右小孩指向空
                    else:
                        parent.right == None
                    return True
                # case2:delete_node 只有左邊的小孩，找左邊小孩中最大的來補
                if delete_node.left != None and delete_node.right == None:
                    # case2-1:delete_node左小孩中最大的node就是delete_node.left，直接將parent與delete_node.left連結
                    if delete_node.left.right == None:
                        parent.left = delete_node.left
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
     
        if target  == root.val:
            return root.val 
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
#     def modify(self,root,target,new_val):

# %%
a = Solution()
root = TreeNode(10) #如此一來root就有val、left、right屬性
a.insert(root,9)
a.insert(root,8)
a.insert(root,7)
a.pre_order(root)
# Out:
# 新節點加到左邊
# 新節點加到左邊
# 新節點加到左邊
# [10]
# [9]
# [8]
# [7]
# [10]

# %% [markdown]
# > 嗯...怎麼pre_order出來的array只有一個值，把過程一步一步print出來看看，發現遞迴的部分沒出錯，值都正確，後來想想應該是因為我在函式中寫了一行preorder = []，才會導致每次重新呼叫pre_order遞迴時，都會重新將array變為空
#
# def pre_order(self,root): # root-->left-->right
#
#         preorder = []
#
#         if root == None:
#             return False
#
#         else:
#             print(preorder)
#             preorder.append(root.val)
#             if root.left != None:
#                 #print(preorder)
#                 Solution().pre_order(root.left)
#             if root.right != None:
#                 Solution().pre_order(root.right)
#         return preorder
#
# > 在思考怎麼解決這個問題時，突然想到在最一開始要初始化root時，也遇過這問題，因此吸取之前的經驗，把創一個空array的程式碼搬到最一開始給root值的地方，測試看看是否成功!

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            if root.left == None:
                root.left = TreeNode(val)
                print("下面沒節點的情況下，將相同的節點加到左邊")
                return True
            else:
                root.left = TreeNode(val)
                TreeNode(val).left = root.left
                print("下面有節點的情況下，將相同的節點加到左邊")
                return True
        
        
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                print("新節點加到左邊")
                return True
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                print("新節點加到右邊")
                return True
            else:
                return Solution().insert(root.right,val)       


  
    def replace(root,target): #要怎麼跟search取得找到的那個target，也就是當下的root所在位置
        
        if root.right == None and root.left != None: # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
            temp = root.left
            while temp.right != None:
                temp = temp.right
        
        # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
        elif root.left == None and root.right != None: 
            temp = root.right
            while temp.left != None:
                temp = temp.left
                
        elif root.left != None and root.right != None :
            temp = root.right
            while temp.left != None:
                temp = temp.left
        
        return temp
            
   
    def pre_order(self,root): # root-->left-->right
        
#         preorder = [] 每次遞迴都會將preorder變為空array
        
        if root == None:
            return False
        
        else:
            preorder.append(root.val)
            print(preorder)
            if root.left != None:
                Solution().pre_order(root.left)
            if root.right != None:
                Solution().pre_order(root.right)
        return preorder
    
            
    def delete(self,root,target):
        
        parent = None
        delete_node = root
        
        #先找到要刪除的那個node
        while target != delete_node.val:
            parent = delete_node
            
            #第一大類:BST中沒有重複值
            if delete_node.left != delete_node.val:
                
                # case1:delete_node沒有任何小孩，直接將delete_node刪除
                if delete_node.left == None and delete_node.right == None:
                    # case1-1:delete_node比parent小，將parent左小孩指向空
                    if delete_node.val < parent.val:
                        parent.left == None
                    # case1-2:delete_node比parent大，將parent右小孩指向空
                    else:
                        parent.right == None
                    return True
                # case2:delete_node 只有左邊的小孩，找左邊小孩中最大的來補
                if delete_node.left != None and delete_node.right == None:
                    # case2-1:delete_node左小孩中最大的node就是delete_node.left，直接將parent與delete_node.left連結
                    if delete_node.left.right == None:
                        parent.left = delete_node.left
                
 

    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
     
        if target  == root.val:
            return root.val 
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
#     def modify(self,root,target,new_val):

# %%
preorder = []
a = Solution()
root = TreeNode(10) #如此一來root就有val、left、right屬性
a.insert(root,9)
a.insert(root,8)
a.insert(root,7)
a.pre_order(root)
# Out:
# 新節點加到左邊
# 新節點加到左邊
# 新節點加到左邊
# [10]
# [10, 9]
# [10, 9, 8]
# [10, 9, 8, 7]
# [10, 9, 8, 7]

# %% [markdown]
# 修改成功!!!

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            if root.left == None:
                root.left = TreeNode(val)
                print("下面沒節點的情況下，將相同的節點加到左邊")
                return True
            else:
                root.left = TreeNode(val)
                TreeNode(val).left = root.left
                print("下面有節點的情況下，將相同的節點加到左邊")
                return True
        
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                print("新節點加到左邊")
                return True
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                print("新節點加到右邊")
                return True
            else:
                return Solution().insert(root.right,val)       


  
    def replace(root,target): #要怎麼跟search取得找到的那個target，也就是當下的root所在位置
        
        if root.right == None and root.left != None: # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
            temp = root.left
            while temp.right != None:
                temp = temp.right
        
        # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
        elif root.left == None and root.right != None: 
            temp = root.right
            while temp.left != None:
                temp = temp.left
                
        elif root.left != None and root.right != None :
            temp = root.right
            while temp.left != None:
                temp = temp.left
        
        return temp
            
   
    def pre_order(self,root): # root-->left-->right

        if root == None:
            return False
        else:
            preorder.append(root.val)
            if root.left != None:
                Solution().pre_order(root.left)
            if root.right != None:
                Solution().pre_order(root.right)
        return preorder
            
    def delete(self,root,target):  
        parent = None
        delete_node = root 
        #先找到要刪除的那個node
        while target != delete_node.val:
            if target <= delete_node.val:
                parent = delete_node
                delete_node = delete_node.left
            if target > delete_node.val:
                parent = delete_node
                delete_node = delete_node.right
                
#         print(parent.val)
#         print(delete_node.val)

        # case1:delete_node沒有任何小孩，直接將delete_node刪除
        if delete_node.left == None and delete_node.right == None:
            # case1-1:delete_node比parent小，將parent左小孩指向空
            if delete_node.val < parent.val:
                parent.left = None
            #case1-2:delete_node比parent大，將parent右小孩指向空
            elif delete_node.val > parent.val:
                parent.right = None
            #return True #記得最後要刪掉

        #第一大類:BST中沒有重複值
        if delete_node.left != delete_node.val:
            # case2:delete_node 只有左邊的小孩，找左邊小孩中最大的來補
            if delete_node.left != None and delete_node.right == None:
                # case2-1:delete_node左小孩中最大的是delete_node.left，直接將parent與delete_node.left連結
                if delete_node.left.right == None:
                        parent.left = delete_node.left
                        
                # case2-2:delete_node.left有right child，找delete_node.left.right中最大來補
                # 當delete_node.left.right指向空，和parent連結
                elif delete_node.left.right != None:
                    while delete_node.left.right.right != None:
                        delete_node.left.right = delete_node.left.right.right
                    parent.left = delete_node.left.right
                    delete_node.left.right.left = delete_node.left
                return True
                        
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
     
        if target  == root.val:
            return root.val 
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
#     def modify(self,root,target,new_val):

# %%
preorder = []
a = Solution()
root = TreeNode(9) #如此一來root就有val、left、right屬性
a.insert(root,8)
a.insert(root,7)
a.insert(root,6)
a.insert(root,5)
a.insert(root,5.5)
a.insert(root,6.5)
a.insert(root,6.7)
a.delete(root,7)
a.pre_order(root)
# Out:
# 新節點加到左邊
# 新節點加到左邊
# 新節點加到左邊
# 新節點加到左邊
# 新節點加到右邊
# 新節點加到右邊
# 新節點加到右邊
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-42-a78eafecae94> in <module>
#      10 a.insert(root,6.7)
#      11 a.delete(root,7)
# ---> 12 a.pre_order(root)
#
# <ipython-input-41-943322277ffd> in pre_order(self, root)
#      65             preorder.append(root.val)
#      66             if root.left != None:
# ---> 67                 Solution().pre_order(root.left)
#      68             if root.right != None:
#      69                 Solution().pre_order(root.right)
#
# <ipython-input-41-943322277ffd> in pre_order(self, root)
#      65             preorder.append(root.val)
#      66             if root.left != None:
# ---> 67                 Solution().pre_order(root.left)
#      68             if root.right != None:
#      69                 Solution().pre_order(root.right)
#
# ...

# %% [markdown]
# case2-2陷入遞迴深度錯誤，應該是我遞迴條件有設錯

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            if root.left == None:
                root.left = TreeNode(val)
                print("下面沒節點的情況下，將相同的節點加到左邊")
                return True
            else:
                root.left = TreeNode(val)
                TreeNode(val).left = root.left
                print("下面有節點的情況下，將相同的節點加到左邊")
                return True
        
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                print("新節點加到左邊")
                return True
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                print("新節點加到右邊")
                return True
            else:
                return Solution().insert(root.right,val)       
  
    def replace(root,target): #要怎麼跟search取得找到的那個target，也就是當下的root所在位置
        
        if root.right == None and root.left != None: # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
            temp = root.left
            while temp.right != None:
                temp = temp.right
        
        # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
        elif root.left == None and root.right != None: 
            temp = root.right
            while temp.left != None:
                temp = temp.left
                
        elif root.left != None and root.right != None :
            temp = root.right
            while temp.left != None:
                temp = temp.left
        
        return temp
            
   
    def pre_order(self,root): # root-->left-->right

        if root == None:
            return False
        else:
            preorder.append(root.val)
            if root.left != None:
                Solution().pre_order(root.left)
            if root.right != None:
                Solution().pre_order(root.right)
        return preorder
            
    def delete(self,root,target):  
        p = None
        d = root 
        
        # case5: delete_node為root，找左邊最大或右邊最小來補
        # case5-1: root沒有右小孩，且root.left沒有右小孩(最大的就是d.left)
        if d.right == None and d.left.right == None:
            d = None
            d = d.left
            return d
        
        
        #先找到要刪除的那個node
        while target != d.val:
            if target <= d.val:
                p = d
                d = d.left
            if target > d.val:
                p = d
                d = d.right
                
#         print(p.val)
#         print(d.val)

        # case1:delete_node沒有任何小孩，直接將delete_node刪除
        if d.left == None and d.right == None:
            # case1-1:delete_node比parent小，將parent左小孩指向空
            if d.val < p.val:
                p.left = None
                return True
            #case1-2:delete_node比parent大，將parent右小孩指向空
            elif d.val > p.val:
                p.right = None
                return True #記得最後要刪掉

        #第一大類:BST中沒有重複值
        if d.left != d.val:
            # case2:delete_node 只有左邊的小孩，找左邊小孩中最大的來補
            if d.left != None and d.right == None:
                # case2-1:delete_node左小孩中最大的是delete_node.left，直接將parent與delete_node.left連結
                if d.left.right == None:
                    p.left = d.left
                    return True
                # case2-2:delete_node.left有right child，找delete_node.left.right中最大來補
                elif d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    p.left = cur
                    cur.left = d.left
                    d = None
                    curp.right = None
                    return True
            # case3:delete_node 只有右邊的小孩，找右邊小孩中最小的來補
            if d.left == None and d.right != None:
                # case3-1: delete_node右小孩中最小的是delete_node.right
                if d.right.left == None:
                    p.left = d.right
                    return True
                # case3-2: delete_node.right有left child，找delete_node.right.left中最小來補
                elif d.right.left != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    d = None
                    curp.left = None
                    return True
            # case4:delete_node 有右邊及左邊的小孩，找右邊小孩中最小的或左邊最大來補
            if d.left != None and d.right != None:
                # case4-1: delete_node只有一個左小孩及一個右小孩
                if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                    p.left = d.left
                    p.left.right = d.right
                    return True
                # case4-2: delete_node的左右小孩皆有左右小孩
                if d.left.left != None and d.left.right != None and d.right.left != None and d.right.right != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    cur.left = d.left
                    d = None
                    curp.left = None
                    return True
            
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
     
        if target  == root.val:
            return root.val 
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
#     def modify(self,root,target,new_val):

# %%
preorder = []
a = Solution()
root = TreeNode(9) #如此一來root就有val、left、right屬性
a.insert(root,5)
a.insert(root,3)
a.pre_order(a.delete(root,9))
# Out:
# 新節點加到左邊
# 新節點加到左邊
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-a71321af42d0> in <module>
#       4 a.insert(root,5)
#       5 a.insert(root,3)
# ----> 6 a.pre_order(a.delete(root,9))
#
# <ipython-input-43-eeada734e18c> in delete(self, root, target)
#      76         if d.right == None and d.left.right == None:
#      77             d = None
# ---> 78             d = d.left
#      79             return d
#      80
#
# AttributeError: 'NoneType' object has no attribute 'left'

# %% [markdown]
# 喔喔因為我已經先把root指定為空，因此root當然不會有left、right這些屬性，因此我想說先給新的root一個空間，叫做new，之後等等刪掉root時就不怕無法連接新的root

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            if root.left == None:
                root.left = TreeNode(val)
                print("下面沒節點的情況下，將相同的節點加到左邊")
                return True
            else:
                root.left = TreeNode(val)
                TreeNode(val).left = root.left
                print("下面有節點的情況下，將相同的節點加到左邊")
                return True
        
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                print("新節點加到左邊")
                return True
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                print("新節點加到右邊")
                return True
            else:
                return Solution().insert(root.right,val)       
  
    def replace(root,target): #要怎麼跟search取得找到的那個target，也就是當下的root所在位置
        
        if root.right == None and root.left != None: # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
            temp = root.left
            while temp.right != None:
                temp = temp.right
        
        # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
        elif root.left == None and root.right != None: 
            temp = root.right
            while temp.left != None:
                temp = temp.left
                
        elif root.left != None and root.right != None :
            temp = root.right
            while temp.left != None:
                temp = temp.left
        
        return temp
            
   
    def pre_order(self,root): # root-->left-->right

        if root == None:
            return False
        else:
            preorder.append(root.val)
            if root.left != None:
                Solution().pre_order(root.left)
            if root.right != None:
                Solution().pre_order(root.right)
        return preorder
            
    def delete(self,root,target):  
        p = None
        d = root 
        
        # case5: delete_node為root，找左邊最大或右邊最小來補
        # case5-1: root沒有右小孩，且root.left沒有右小孩(最大的就是d.left)
        if d.right == None and d.left.right == None:
            new = d.left
            d = None
            return new
        
        
        #先找到要刪除的那個node
        while target != d.val:
            if target <= d.val:
                p = d
                d = d.left
            if target > d.val:
                p = d
                d = d.right
                
#         print(p.val)
#         print(d.val)

        # case1:delete_node沒有任何小孩，直接將delete_node刪除
        if d.left == None and d.right == None:
            # case1-1:delete_node比parent小，將parent左小孩指向空
            if d.val < p.val:
                p.left = None
                return True
            #case1-2:delete_node比parent大，將parent右小孩指向空
            elif d.val > p.val:
                p.right = None
                return True #記得最後要刪掉

        #第一大類:BST中沒有重複值
        if d.left != d.val:
            # case2:delete_node 只有左邊的小孩，找左邊小孩中最大的來補
            if d.left != None and d.right == None:
                # case2-1:delete_node左小孩中最大的是delete_node.left，直接將parent與delete_node.left連結
                if d.left.right == None:
                    p.left = d.left
                    return True
                # case2-2:delete_node.left有right child，找delete_node.left.right中最大來補
                elif d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    p.left = cur
                    cur.left = d.left
                    d = None
                    curp.right = None
                    return True
            # case3:delete_node 只有右邊的小孩，找右邊小孩中最小的來補
            if d.left == None and d.right != None:
                # case3-1: delete_node右小孩中最小的是delete_node.right
                if d.right.left == None:
                    p.left = d.right
                    return True
                # case3-2: delete_node.right有left child，找delete_node.right.left中最小來補
                elif d.right.left != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    d = None
                    curp.left = None
                    return True
            # case4:delete_node 有右邊及左邊的小孩，找右邊小孩中最小的或左邊最大來補
            if d.left != None and d.right != None:
                # case4-1: delete_node只有一個左小孩及一個右小孩
                if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                    p.left = d.left
                    p.left.right = d.right
                    return True
                # case4-2: delete_node的左右小孩皆有左右小孩
                if d.left.left != None and d.left.right != None and d.right.left != None and d.right.right != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    cur.left = d.left
                    d = None
                    curp.left = None
                    return True
            
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
     
        if target  == root.val:
            return root.val 
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
#     def modify(self,root,target,new_val):

# %%
preorder = []
a = Solution()
root = TreeNode(9) #如此一來root就有val、left、right屬性
a.insert(root,5)
a.insert(root,3)
a.pre_order(a.delete(root,9))
# Out:
# 新節點加到左邊
# 新節點加到左邊
# [5, 3]

# %% [markdown]
# 刪除root的正確觀念已經有了，接著寫刪除root的其他case

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            if root.left == None:
                root.left = TreeNode(val)
                print("下面沒節點的情況下，將相同的節點加到左邊")
                return True
            else:
                root.left = TreeNode(val)
                TreeNode(val).left = root.left
                print("下面有節點的情況下，將相同的節點加到左邊")
                return True
        
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                print("新節點加到左邊")
                return True
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                print("新節點加到右邊")
                return True
            else:
                return Solution().insert(root.right,val)       
  
    def replace(root,target): #要怎麼跟search取得找到的那個target，也就是當下的root所在位置
        
        if root.right == None and root.left != None: # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
            temp = root.left
            while temp.right != None:
                temp = temp.right
        
        # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
        elif root.left == None and root.right != None: 
            temp = root.right
            while temp.left != None:
                temp = temp.left
                
        elif root.left != None and root.right != None :
            temp = root.right
            while temp.left != None:
                temp = temp.left
        
        return temp
            
   
    def pre_order(self,root): # root-->left-->right

        if root == None:
            return False
        else:
            preorder.append(root.val)
            if root.left != None:
                Solution().pre_order(root.left)
            if root.right != None:
                Solution().pre_order(root.right)
        return preorder
            
    def delete(self,root,target):  
        p = None
        d = root 
        
        # case5: delete_node為root，找左邊最大或右邊最小來補
        # case5-1: root沒有右小孩，且root.left沒有右小孩(最大的就是d.left)
        if d.right == None and d.left.right == None:
            new = d.left
            d = None
            return new
        # case5-2: root沒有左小孩，且root.right沒有左小孩(最小的就是d.right)
        if d.left == None and d.right.left == None:
            new = d.right
            d = None
            return new   
        # case5-3: root只有左右各一個小孩，找左或右小孩來補
        if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
            new = d.left
            new.right = d.right
            d = None
            return new
        # case5-4: d的左小孩只要有右小孩，找右小孩中最大的
        if d.left.right != None:
            curp = d.left
            cur = d.left.right
            while cur.right != None:
                curp = cur
                cur = cur.right
            cur.left = d.left
            d = None
            cur.right = None
            return cur
        
        # case5-5: d的右小孩只要有左小孩，找左小孩中最小的
        # case5-6: d的左小孩只要有右小孩，找右小孩中最大的;d的右小孩只要有左小孩，找左小孩中最小的
        
        #先找到要刪除的那個node
        while target != d.val:
            if target <= d.val:
                p = d
                d = d.left
            if target > d.val:
                p = d
                d = d.right
                
#         print(p.val)
#         print(d.val)

        # case1:delete_node沒有任何小孩，直接將delete_node刪除
        if d.left == None and d.right == None:
            # case1-1:delete_node比parent小，將parent左小孩指向空
            if d.val < p.val:
                p.left = None
                return True
            #case1-2:delete_node比parent大，將parent右小孩指向空
            elif d.val > p.val:
                p.right = None
                return True #記得最後要刪掉

        #第一大類:BST中沒有重複值
        if d.left != d.val:
            # case2:delete_node 只有左邊的小孩，找左邊小孩中最大的來補
            if d.left != None and d.right == None:
                # case2-1:delete_node左小孩中最大的是delete_node.left，直接將parent與delete_node.left連結
                if d.left.right == None:
                    p.left = d.left
                    return True
                # case2-2:delete_node.left有right child，找delete_node.left.right中最大來補
                elif d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    p.left = cur
                    cur.left = d.left
                    d = None
                    curp.right = None
                    return True
            # case3:delete_node 只有右邊的小孩，找右邊小孩中最小的來補
            if d.left == None and d.right != None:
                # case3-1: delete_node右小孩中最小的是delete_node.right
                if d.right.left == None:
                    p.left = d.right
                    return True
                # case3-2: delete_node.right有left child，找delete_node.right.left中最小來補
                elif d.right.left != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    d = None
                    curp.left = None
                    return True
            # case4:delete_node 有右邊及左邊的小孩，找右邊小孩中最小的或左邊最大來補
            if d.left != None and d.right != None:
                # case4-1: delete_node只有一個左小孩及一個右小孩
                if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                    p.left = d.left
                    p.left.right = d.right
                    return True
                # case4-2: delete_node的左右小孩皆有左右小孩
                if d.left.left != None and d.left.right != None and d.right.left != None and d.right.right != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    cur.left = d.left
                    d = None
                    curp.left = None
                    return True
            
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
     
        if target  == root.val:
            return root.val 
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
#     def modify(self,root,target,new_val):

# %%
preorder = []
a = Solution()
root = TreeNode(9) #如此一來root就有val、left、right屬性
a.insert(root,5)
a.insert(root,3)
a.insert(root,2)
a.insert(root,3.5)
a.insert(root,6)
a.insert(root,7)
a.pre_order(a.delete(root,9))
# Out:
# 新節點加到左邊
# 新節點加到左邊
# 新節點加到左邊
# 新節點加到右邊
# 新節點加到右邊
# 新節點加到右邊
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-48-f5a61d78600c> in <module>
#       8 a.insert(root,6)
#       9 a.insert(root,7)
# ---> 10 a.pre_order(a.delete(root,9))
#
# <ipython-input-47-4d97e839aa1b> in pre_order(self, root)
#      63             preorder.append(root.val)
#      64             if root.left != None:
# ---> 65                 Solution().pre_order(root.left)
#      66             if root.right != None:
#      67                 Solution().pre_order(root.right)
#
# <ipython-input-47-4d97e839aa1b> in pre_order(self, root)
#      65                 Solution().pre_order(root.left)
#      66             if root.right != None:
# ---> 67                 Solution().pre_order(root.right)
#      68         return preorder
#      69
#
# <ipython-input-47-4d97e839aa1b> in pre_order(self, root)
# ...

# %% [markdown]
# case5-4陷入深度地迴錯誤
#
# 這個case是想處理不論root是否有右小孩，都從左小孩中找出最大的來補，但由於我條件並沒有設d.right == None，因此有可能遇到root左右都有小孩，但右小孩沒有與新的root連結;另外在找到替補值，變成新的root之後，也要同時把curp指向空

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            if root.left == None:
                root.left = TreeNode(val)
                print("下面沒節點的情況下，將相同的節點加到左邊")
                return True
            else:
                root.left = TreeNode(val)
                TreeNode(val).left = root.left
                print("下面有節點的情況下，將相同的節點加到左邊")
                return True
        
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                print("新節點加到左邊")
                return True
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                print("新節點加到右邊")
                return True
            else:
                return Solution().insert(root.right,val)       
  
    def replace(root,target): #要怎麼跟search取得找到的那個target，也就是當下的root所在位置
        
        if root.right == None and root.left != None: # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
            temp = root.left
            while temp.right != None:
                temp = temp.right
        
        # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
        elif root.left == None and root.right != None: 
            temp = root.right
            while temp.left != None:
                temp = temp.left
                
        elif root.left != None and root.right != None :
            temp = root.right
            while temp.left != None:
                temp = temp.left
        
        return temp
            
   
    def pre_order(self,root): # root-->left-->right

        if root == None:
            return False
        else:
            preorder.append(root.val)
            if root.left != None:
                Solution().pre_order(root.left)
            if root.right != None:
                Solution().pre_order(root.right)
        return preorder
            
    def delete(self,root,target):  
        p = None
        d = root 
        
        # case5: delete_node為root，找左邊最大或右邊最小來補
        # case5-1: root沒有右小孩，且root.left沒有右小孩(最大的就是d.left)
        if d.right == None and d.left.right == None:
            new = d.left
            d = None
            return new
        # case5-2: root沒有左小孩，且root.right沒有左小孩(最小的就是d.right)
        if d.left == None and d.right.left == None:
            new = d.right
            d = None
            return new   
        # case5-3: root只有左右各一個小孩，找左或右小孩來補
        if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
            new = d.left
            new.right = d.right
            d = None
            return new
        # case5-4: d的左小孩只要有右小孩，找右小孩中最大的
        if d.left.right != None:
            curp = d.left
            cur = d.left.right
            while cur.right != None:
                curp = cur
                cur = cur.right
            cur.left = d.left
            cur.right = d.right
            d = None
            curp.right = None
            return cur
        
        # case5-5: d的右小孩只要有左小孩，找左小孩中最小的
        # case5-6: d的左小孩只要有右小孩，找右小孩中最大的;d的右小孩只要有左小孩，找左小孩中最小的
        
        #先找到要刪除的那個node
        while target != d.val:
            if target <= d.val:
                p = d
                d = d.left
            if target > d.val:
                p = d
                d = d.right
                
#         print(p.val)
#         print(d.val)

        # case1:delete_node沒有任何小孩，直接將delete_node刪除
        if d.left == None and d.right == None:
            # case1-1:delete_node比parent小，將parent左小孩指向空
            if d.val < p.val:
                p.left = None
                return True
            #case1-2:delete_node比parent大，將parent右小孩指向空
            elif d.val > p.val:
                p.right = None
                return True #記得最後要刪掉

        #第一大類:BST中沒有重複值
        if d.left != d.val:
            # case2:delete_node 只有左邊的小孩，找左邊小孩中最大的來補
            if d.left != None and d.right == None:
                # case2-1:delete_node左小孩中最大的是delete_node.left，直接將parent與delete_node.left連結
                if d.left.right == None:
                    p.left = d.left
                    return True
                # case2-2:delete_node.left有right child，找delete_node.left.right中最大來補
                elif d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    p.left = cur
                    cur.left = d.left
                    d = None
                    curp.right = None
                    return True
            # case3:delete_node 只有右邊的小孩，找右邊小孩中最小的來補
            if d.left == None and d.right != None:
                # case3-1: delete_node右小孩中最小的是delete_node.right
                if d.right.left == None:
                    p.left = d.right
                    return True
                # case3-2: delete_node.right有left child，找delete_node.right.left中最小來補
                elif d.right.left != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    d = None
                    curp.left = None
                    return True
            # case4:delete_node 有右邊及左邊的小孩，找右邊小孩中最小的或左邊最大來補
            if d.left != None and d.right != None:
                # case4-1: delete_node只有一個左小孩及一個右小孩
                if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                    p.left = d.left
                    p.left.right = d.right
                    return True
                # case4-2: delete_node的左右小孩皆有左右小孩
                if d.left.left != None and d.left.right != None and d.right.left != None and d.right.right != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    cur.left = d.left
                    d = None
                    curp.left = None
                    return True
            
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
     
        if target  == root.val:
            return root.val 
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
#     def modify(self,root,target,new_val):

# %%
preorder = []
a = Solution()
root = TreeNode(9) #如此一來root就有val、left、right屬性

# %%
a.insert(root,5)
a.insert(root,3)
a.insert(root,2)
a.insert(root,3.5)
a.insert(root,6)
a.insert(root,7)
a.pre_order(a.delete(root,9))

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            if root.left == None:
                root.left = TreeNode(val)
                print("下面沒節點的情況下，將相同的節點加到左邊")
                return True
            else:
                root.left = TreeNode(val)
                TreeNode(val).left = root.left
                print("下面有節點的情況下，將相同的節點加到左邊")
                return True
        
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                print("新節點加到左邊")
                return True
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                print("新節點加到右邊")
                return True
            else:
                return Solution().insert(root.right,val)       
  
    def replace(root,target): #要怎麼跟search取得找到的那個target，也就是當下的root所在位置
        
        if root.right == None and root.left != None: # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
            temp = root.left
            while temp.right != None:
                temp = temp.right
        
        # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
        elif root.left == None and root.right != None: 
            temp = root.right
            while temp.left != None:
                temp = temp.left
                
        elif root.left != None and root.right != None :
            temp = root.right
            while temp.left != None:
                temp = temp.left
        
        return temp
            
   
    def pre_order(self,root): # root-->left-->right

        if root == None:
            return False
        else:
            preorder.append(root.val)
            if root.left != None:
                Solution().pre_order(root.left)
            if root.right != None:
                Solution().pre_order(root.right)
        return preorder
            
    def delete(self,root,target):  
        p = None
        d = root 
        
        # case5: delete_node為root，找左邊最大或右邊最小來補
        # case5-1: root沒有右小孩，且root.left沒有右小孩(最大的就是d.left)
        if d.right == None and d.left.right == None:
            new = d.left
            d = None
            print("case5-1")
            return new
        # case5-2: root沒有左小孩，且root.right沒有左小孩(最小的就是d.right)
        if d.left == None and d.right.left == None:
            new = d.right
            d = None
            print("case5-2")
            return new   
        # case5-3: root只有左右各一個小孩，找左或右小孩來補
        if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
            new = d.left
            new.right = d.right
            d = None
            print("case5-3")
            return new
        # case5-4: d的左小孩只要有右小孩，找右小孩中最大的
        if d.left.right != None:
            curp = d.left
            cur = d.left.right
            while cur.right != None:
                curp = cur
                cur = cur.right
            cur.left = d.left
            cur.right = d.right
            d = None
            curp.right = None
            print("case5-4")
            return cur
        
        # case5-5: d的右小孩只要有左小孩，找左小孩中最小的
        if d.right.left != None:
            curp = d.right
            cur = d.right.left
            while cur.left != None:
                curp = cur
                cur = cur.left
            cur.right = d.right
            cur.left = d.left
            d = None
            curp.left = None
            print("case5-5")
            return cur
        
        #先找到要刪除的那個node
        while target != d.val:
            if target <= d.val:
                p = d
                d = d.left
            if target > d.val:
                p = d
                d = d.right
                
#         print(p.val)
#         print(d.val)

        # case1:delete_node沒有任何小孩，直接將delete_node刪除
        if d.left == None and d.right == None:
            # case1-1:delete_node比parent小，將parent左小孩指向空
            if d.val < p.val:
                p.left = None
                print("case1-1")
                return True
            #case1-2:delete_node比parent大，將parent右小孩指向空
            elif d.val > p.val:
                p.right = None
                print("case1-2")
                return True #記得最後要刪掉

        #第一大類:BST中沒有重複值
        if d.left != d.val:
            # case2:delete_node 只有左邊的小孩，找左邊小孩中最大的來補
            if d.left != None and d.right == None:
                # case2-1:delete_node左小孩中最大的是delete_node.left，直接將parent與delete_node.left連結
                if d.left.right == None:
                    p.left = d.left
                    print("case2-1")
                    return True
                # case2-2:delete_node.left有right child，找delete_node.left.right中最大來補
                elif d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    p.left = cur
                    cur.left = d.left
                    d = None
                    curp.right = None
                    print("case2-2")
                    return True
            # case3:delete_node 只有右邊的小孩，找右邊小孩中最小的來補
            if d.left == None and d.right != None:
                # case3-1: delete_node右小孩中最小的是delete_node.right
                if d.right.left == None:
                    p.left = d.right
                    print("case3-1")
                    return True
                # case3-2: delete_node.right有left child，找delete_node.right.left中最小來補
                elif d.right.left != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    d = None
                    curp.left = None
                    print("case3-2")
                    return True
            # case4:delete_node 有右邊及左邊的小孩，找右邊小孩中最小的或左邊最大來補
            if d.left != None and d.right != None:
                # case4-1: delete_node只有一個左小孩及一個右小孩
                if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                    p.left = d.left
                    p.left.right = d.right
                    print("case4-1")
                    return True
                # case4-2: delete_node的左右小孩皆有左右小孩
                if d.left.left != None and d.left.right != None and d.right.left != None and d.right.right != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    cur.left = d.left
                    d = None
                    curp.left = None
                    print("case4-2")
                    return True
        #第二大類:BST中有重複值
        elif d.left == d.val:
#             # case6-1:刪除值的leftchild沒有right child
#             end = d.left
#             while end == target:
#                 d = end
#                 end = end.left
#             if end == None:
#                 p.left = None
            
            
            # case6-3:刪除值之下沒有任何child
            end = d.left
            while end == target:
                d = end
                end = end.left
            if end == None:
                p.left = None
            
                
            
            
            
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
     
        if target  == root.val:
            return root.val 
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
#     def modify(self,root,target,new_val):

# %%
preorder = []
a = Solution()
root = TreeNode(9) #如此一來root就有val、left、right屬性

# %%
a.insert(root,8)
a.insert(root,7)
a.insert(root,7)
a.insert(root,7)
a.delete(root,7)
a.pre_order(root)
# Out:
# 新節點加到左邊
# 新節點加到左邊
# 下面沒節點的情況下，將相同的節點加到左邊
# 下面有節點的情況下，將相同的節點加到左邊
# [9, 8, 7, 7]

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            if root.left == None:
                root.left = TreeNode(val)
                print("下面沒節點的情況下，將相同的節點加到左邊")
                return True
            else:
                root.left = TreeNode(val)
                TreeNode(val).left = root.left
                print("下面有節點的情況下，將相同的節點加到左邊")
                return True
        
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                print("新節點加到左邊")
                return True
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                print("新節點加到右邊")
                return True
            else:
                return Solution().insert(root.right,val)       
  
    def replace(root,target): #要怎麼跟search取得找到的那個target，也就是當下的root所在位置
        
        if root.right == None and root.left != None: # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
            temp = root.left
            while temp.right != None:
                temp = temp.right
        
        # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
        elif root.left == None and root.right != None: 
            temp = root.right
            while temp.left != None:
                temp = temp.left
                
        elif root.left != None and root.right != None :
            temp = root.right
            while temp.left != None:
                temp = temp.left
        
        return temp
            
   
    def pre_order(self,root): # root-->left-->right

        if root == None:
            return False
        else:
            preorder.append(root.val)
            if root.left != None:
                Solution().pre_order(root.left)
            if root.right != None:
                Solution().pre_order(root.right)
        return preorder
            
    def delete(self,root,target):  
        p = None
        d = root 
        
        
        
        #先找到要刪除的那個node
        while target != d.val:
            if target <= d.val:
                p = d
                d = d.left
            if target > d.val:
                p = d
                d = d.right
                
#         print(p.val)
#         print(d.val)

        # case1:delete_node沒有任何小孩，直接將delete_node刪除
        if d.left == None and d.right == None:
            # case1-1:delete_node比parent小，將parent左小孩指向空
            if d.val < p.val:
                p.left = None
                print("case1-1")
            #case1-2:delete_node比parent大，將parent右小孩指向空
            elif d.val > p.val:
                p.right = None
                print("case1-2")

        #第一大類:BST中沒有重複值
        if d.left.val != target:
            # case2:delete_node 只有左邊的小孩，找左邊小孩中最大的來補
            if d.left != None and d.right == None:
                # case2-1:delete_node左小孩中最大的是delete_node.left，直接將parent與delete_node.left連結
                if d.left.right == None:
                    p.left = d.left
                    print("case2-1")
                # case2-2:delete_node.left有right child，找delete_node.left.right中最大來補
                elif d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    p.left = cur
                    cur.left = d.left
                    d = None
                    curp.right = None
                    print("case2-2")
            # case3:delete_node 只有右邊的小孩，找右邊小孩中最小的來補
            if d.left == None and d.right != None:
                # case3-1: delete_node右小孩中最小的是delete_node.right
                if d.right.left == None:
                    p.left = d.right
                    print("case3-1")
                # case3-2: delete_node.right有left child，找delete_node.right.left中最小來補
                elif d.right.left != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    d = None
                    curp.left = None
                    print("case3-2")
            # case4:delete_node 有右邊及左邊的小孩，找右邊小孩中最小的或左邊最大來補
            if d.left != None and d.right != None:
                # case4-1: delete_node只有一個左小孩及一個右小孩
                if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                    p.left = d.left
                    p.left.right = d.right
                    print("case4-1")
                # case4-2: delete_node的左右小孩皆有左右小孩
                if d.left.left != None and d.left.right != None and d.right.left != None and d.right.right != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    cur.left = d.left
                    d = None
                    curp.left = None
                    print("case4-2")
            # case5: delete_node為root，找左邊最大或右邊最小來補
            # case5-1: root沒有右小孩，且root.left沒有右小孩(最大的就是d.left)
            if d.right == None and d.left.right == None:
                new = d.left
                d = None
                print("case5-1")
                return new
            # case5-2: root沒有左小孩，且root.right沒有左小孩(最小的就是d.right)
            if d.left == None and d.right.left == None:
                new = d.right
                d = None
                print("case5-2")
                return new   
            # case5-3: root只有左右各一個小孩，找左或右小孩來補
            if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                new = d.left
                new.right = d.right
                d = None
                print("case5-3")
                return new
            # case5-4: d的左小孩只要有右小孩，找右小孩中最大的
            if d.left.right != None:
                curp = d.left
                cur = d.left.right
                while cur.right != None:
                    curp = cur
                    cur = cur.right
                cur.left = d.left
                cur.right = d.right
                d = None
                curp.right = None
                print("case5-4")
                return cur
        
            # case5-5: d的右小孩只要有左小孩，找左小孩中最小的
            if d.right.left != None:
                curp = d.right
                cur = d.right.left
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                cur.right = d.right
                cur.left = d.left
                d = None
                curp.left = None
                print("case5-5")
                return cur    
                
        #第二大類:BST中有重複值
        elif d.left.val == target and d.val != target:
            # case6-1:刪除值之下有小孩
            end = d.left
            while end.val == target and end.left != None:
                d = end
                end = end.left
            p.left = end
            print("case6-1")
    
            # case6-2:刪除值之下沒有任何child
            end = d.left
            while end.val == target:
                d = end
                end = end.left
            
            p.left = None
            print("case6-2")
            
        # case6-3: 刪除值為root，且root.right沒左小孩
        elif d.left.val == target and d.val == target:
            if d.right.left == None:
                end = d.left
                new = d.right
                while end.val == target and end.left != None:
                    d = end
                    end = end.left
                new.left = end
                print("case6-3")
                return new
            # case6-4: 刪除值為root，且root.right有左小孩
            elif d.right.left != None:
                curp = d.right
                cur = curp.left
                end = d.left
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                
                while end.val == target and end.left != None:
                    d = end
                    end = end.left
                    
               
                cur.right = d.right
                cur.left = end
                curp.left = None
                print("case6-4")
                return cur
            
            
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
     
        if target  == root.val:
            return root.val 
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
#     def modify(self,root,target,new_val):

# %%
preorder = []
a = Solution()
root = TreeNode(10) #如此一來root就有val、left、right屬性

# %%
a.insert(root,10)
a.insert(root,7)
a.insert(root,6)
a.insert(root,7.5)
a.insert(root,12)
a.insert(root,10)
a.insert(root,10.5)
a.pre_order(a.delete(root,10))
# Out:
# 下面沒節點的情況下，將相同的節點加到左邊
# 新節點加到左邊
# 新節點加到左邊
# 新節點加到右邊
# 新節點加到右邊
# 下面有節點的情況下，將相同的節點加到左邊
# 新節點加到左邊
# case6-4
# [10.5, 10, 12]

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            if root.left == None:
                root.left = TreeNode(val)
                print("下面沒節點的情況下，將相同的節點加到左邊")
                return True
            else:
                root.left = TreeNode(val)
                TreeNode(val).left = root.left
                print("下面有節點的情況下，將相同的節點加到左邊")
                return True
        
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                print("新節點加到左邊")
                return True
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                print("新節點加到右邊")
                return True
            else:
                return Solution().insert(root.right,val)       
  
    def replace(root,target): #要怎麼跟search取得找到的那個target，也就是當下的root所在位置
        
        if root.right == None and root.left != None: # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
            temp = root.left
            while temp.right != None:
                temp = temp.right
        
        # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
        elif root.left == None and root.right != None: 
            temp = root.right
            while temp.left != None:
                temp = temp.left
                
        elif root.left != None and root.right != None :
            temp = root.right
            while temp.left != None:
                temp = temp.left
        
        return temp
            
   
    def pre_order(self,root): # root-->left-->right

        if root == None:
            return False
        else:
            preorder.append(root.val)
            if root.left != None:
                Solution().pre_order(root.left)
            if root.right != None:
                Solution().pre_order(root.right)
        return preorder
            
    def delete(self,root,target):  
        p = None
        d = root 
        
        
        
        #先找到要刪除的那個node
        while target != d.val:
            if target <= d.val:
                p = d
                d = d.left
            if target > d.val:
                p = d
                d = d.right
                
#         print(p.val)
#         print(d.val)

        # case1:delete_node沒有任何小孩，直接將delete_node刪除
        if d.left == None and d.right == None:
            # case1-1:delete_node比parent小，將parent左小孩指向空
            if d.val < p.val:
                p.left = None
                print("case1-1")
            #case1-2:delete_node比parent大，將parent右小孩指向空
            elif d.val > p.val:
                p.right = None
                print("case1-2")

        #第一大類:BST中沒有重複值
        if d.left.val != target:
            # case2:delete_node 只有左邊的小孩，找左邊小孩中最大的來補
            if d.left != None and d.right == None:
                # case2-1:delete_node左小孩中最大的是delete_node.left，直接將parent與delete_node.left連結
                if d.left.right == None:
                    p.left = d.left
                    print("case2-1")
                # case2-2:delete_node.left有right child，找delete_node.left.right中最大來補
                elif d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    p.left = cur
                    cur.left = d.left
                    d = None
                    curp.right = None
                    print("case2-2")
            # case3:delete_node 只有右邊的小孩，找右邊小孩中最小的來補
            if d.left == None and d.right != None:
                # case3-1: delete_node右小孩中最小的是delete_node.right
                if d.right.left == None:
                    p.left = d.right
                    print("case3-1")
                # case3-2: delete_node.right有left child，找delete_node.right.left中最小來補
                elif d.right.left != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    d = None
                    curp.left = None
                    print("case3-2")
            # case4:delete_node 有右邊及左邊的小孩，找右邊小孩中最小的或左邊最大來補
            if d.left != None and d.right != None:
                # case4-1: delete_node只有一個左小孩及一個右小孩
                if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                    p.left = d.left
                    p.left.right = d.right
                    print("case4-1")
                # case4-2: delete_node的左右小孩皆有左右小孩
                if d.left.left != None and d.left.right != None and d.right.left != None and d.right.right != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    cur.left = d.left
                    d = None
                    curp.left = None
                    print("case4-2")
            # case5: delete_node為root，找左邊最大或右邊最小來補
            # case5-1: root沒有右小孩，且root.left沒有右小孩(最大的就是d.left)
            if d.right == None and d.left.right == None:
                new = d.left
                d = None
                print("case5-1")
                return new
            # case5-2: root沒有左小孩，且root.right沒有左小孩(最小的就是d.right)
            if d.left == None and d.right.left == None:
                new = d.right
                d = None
                print("case5-2")
                return new   
            # case5-3: root只有左右各一個小孩，找左或右小孩來補
            if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                new = d.left
                new.right = d.right
                d = None
                print("case5-3")
                return new
            # case5-4: d的左小孩只要有右小孩，找右小孩中最大的
            if d.left.right != None:
                curp = d.left
                cur = d.left.right
                while cur.right != None:
                    curp = cur
                    cur = cur.right
                cur.left = d.left
                cur.right = d.right
                d = None
                curp.right = None
                print("case5-4")
                return cur
        
            # case5-5: d的右小孩只要有左小孩，找左小孩中最小的
            if d.right.left != None:
                curp = d.right
                cur = d.right.left
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                cur.right = d.right
                cur.left = d.left
                d = None
                curp.left = None
                print("case5-5")
                return cur    
                
        #第二大類:BST中有重複值
        elif d.left.val == target and d.val != target:
            # case6-1:刪除值之下有小孩
            end = d.left
            while end.val == target and end.left != None:
                d = end
                end = end.left
            p.left = end
            print("case6-1")
    
            # case6-2:刪除值之下沒有任何child
            end = d.left
            while end.val == target:
                d = end
                end = end.left
            
            p.left = None
            print("case6-2")
            
        # case6-3: 刪除值為root，且root.right沒左小孩
        elif d.left.val == target and d.val == target:
            if d.right.left == None:
                end = d.left
                new = d.right
                while end.val == target and end.left != None:
                    d = end
                    end = end.left
                new.left = end
                print("case6-3")
                return new
            # case6-4: 刪除值為root，且root.right有左小孩
            elif d.right.left != None:
                curp = d.right
                cur = curp.left
                end = d.left
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                print(cur.val)
                while end.val == target and end.left != None:
                    d = end
                    end = end.left
                print(end.val)  
#                 cur.right = d.right
#                 cur.left = end
#                 curp.left = None
                print("case6-4")
#                 return cur
            
            
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
     
        if target  == root.val:
            return root.val 
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
#     def modify(self,root,target,new_val):

# %%
preorder = []
a = Solution()
root = TreeNode(10) #如此一來root就有val、left、right屬性

# %%
a.insert(root,10)
a.insert(root,7)
a.insert(root,6)
a.insert(root,7.5)
a.insert(root,12)
a.insert(root,11)
a.insert(root,10.5)
a.pre_order(a.delete(root,10))
# Out:
# 下面沒節點的情況下，將相同的節點加到左邊
# 新節點加到左邊
# 新節點加到左邊
# 新節點加到右邊
# 新節點加到右邊
# 新節點加到左邊
# 新節點加到左邊
# 10.5
# 7
# case6-4
# False

# %% [markdown]
# 11/16 將insert的部分改成助教要求的格式

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            new = TreeNode(val)
            new.left = root.left
            root.left = new
            #print("下面有節點的情況下，將相同的節點加到左邊")
            return root.left
          
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                #print("新節點加到左邊")
                return root.left
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                #print("新節點加到右邊")
                return root.right
            else:
                return Solution().insert(root.right,val)       
  
    def replace(root,target): #要怎麼跟search取得找到的那個target，也就是當下的root所在位置
        
        if root.right == None and root.left != None: # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
            temp = root.left
            while temp.right != None:
                temp = temp.right
        
        # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
        elif root.left == None and root.right != None: 
            temp = root.right
            while temp.left != None:
                temp = temp.left
                
        elif root.left != None and root.right != None :
            temp = root.right
            while temp.left != None:
                temp = temp.left
        
        return temp
            
   
    def pre_order(self,root): # root-->left-->right

        if root == None:
            return False
        else:
            preorder.append(root.val)
            if root.left != None:
                Solution().pre_order(root.left)
            if root.right != None:
                Solution().pre_order(root.right)
        return preorder
            
    def delete(self,root,target):  
        p = None
        d = root 
        
        
        
        #先找到要刪除的那個node
        while target != d.val:
            if target <= d.val:
                p = d
                d = d.left
            if target > d.val:
                p = d
                d = d.right
                
#         print(p.val)
#         print(d.val)

        # case1:delete_node沒有任何小孩，直接將delete_node刪除
        if d.left == None and d.right == None:
            # case1-1:delete_node比parent小，將parent左小孩指向空
            if d.val < p.val:
                p.left = None
                print("case1-1")
            #case1-2:delete_node比parent大，將parent右小孩指向空
            elif d.val > p.val:
                p.right = None
                print("case1-2")

        #第一大類:BST中沒有重複值
        if d.left.val != target:
            # case2:delete_node 只有左邊的小孩，找左邊小孩中最大的來補
            if d.left != None and d.right == None:
                # case2-1:delete_node左小孩中最大的是delete_node.left，直接將parent與delete_node.left連結
                if d.left.right == None:
                    p.left = d.left
                    print("case2-1")
                # case2-2:delete_node.left有right child，找delete_node.left.right中最大來補
                elif d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    p.left = cur
                    cur.left = d.left
                    d = None
                    curp.right = None
                    print("case2-2")
            # case3:delete_node 只有右邊的小孩，找右邊小孩中最小的來補
            if d.left == None and d.right != None:
                # case3-1: delete_node右小孩中最小的是delete_node.right
                if d.right.left == None:
                    p.left = d.right
                    print("case3-1")
                # case3-2: delete_node.right有left child，找delete_node.right.left中最小來補
                elif d.right.left != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    d = None
                    curp.left = None
                    print("case3-2")
            # case4:delete_node 有右邊及左邊的小孩，找右邊小孩中最小的或左邊最大來補
            if d.left != None and d.right != None:
                # case4-1: delete_node只有一個左小孩及一個右小孩
                if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                    p.left = d.left
                    p.left.right = d.right
                    print("case4-1")
                # case4-2: delete_node的左右小孩皆有左右小孩
                if d.left.left != None and d.left.right != None and d.right.left != None and d.right.right != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    cur.left = d.left
                    d = None
                    curp.left = None
                    print("case4-2")
            # case5: delete_node為root，找左邊最大或右邊最小來補
            # case5-1: root沒有右小孩，且root.left沒有右小孩(最大的就是d.left)
            if d.right == None and d.left.right == None:
                new = d.left
                d = None
                print("case5-1")
                return new
            # case5-2: root沒有左小孩，且root.right沒有左小孩(最小的就是d.right)
            if d.left == None and d.right.left == None:
                new = d.right
                d = None
                print("case5-2")
                return new   
            # case5-3: root只有左右各一個小孩，找左或右小孩來補
            if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                new = d.left
                new.right = d.right
                d = None
                print("case5-3")
                return new
            # case5-4: d的左小孩只要有右小孩，找右小孩中最大的
            if d.left.right != None:
                curp = d.left
                cur = d.left.right
                while cur.right != None:
                    curp = cur
                    cur = cur.right
                cur.left = d.left
                cur.right = d.right
                d = None
                curp.right = None
                print("case5-4")
                return cur
        
            # case5-5: d的右小孩只要有左小孩，找左小孩中最小的
            if d.right.left != None:
                curp = d.right
                cur = d.right.left
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                cur.right = d.right
                cur.left = d.left
                d = None
                curp.left = None
                print("case5-5")
                return cur    
                
        #第二大類:BST中有重複值
        elif d.left.val == target and d.val != target:
            # case6-1:刪除值之下有小孩
            end = d.left
            while end.val == target and end.left != None:
                d = end
                end = end.left
            p.left = end
            print("case6-1")
    
            # case6-2:刪除值之下沒有任何child
            end = d.left
            while end.val == target:
                d = end
                end = end.left
            
            p.left = None
            print("case6-2")
            
        # case6-3: 刪除值為root，且root.right沒左小孩
        elif d.left.val == target and d.val == target:
            if d.right.left == None:
                end = d.left
                new = d.right
                while end.val == target and end.left != None:
                    d = end
                    end = end.left
                new.left = end
                print("case6-3")
                return new
            # case6-4: 刪除值為root，且root.right有左小孩
            elif d.right.left != None:
                curp = d.right
                
                cur = curp.left
                end = d.left
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                print(cur.val)
                while end.val == target and end.left != None:
                    d = end
                    end = end.left
                print(end.val)  
                cur.right = d.right
                cur.left = end
                curp.left = None
                
                print("case6-4")
                return cur
            
            
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
     
        if target  == root.val:
            return root.val 
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
#     def modify(self,root,target,new_val):

# %%
root1 = TreeNode(5)
root1.left = TreeNode(3)
root1.left.left = TreeNode(3)
root1.left.left.left = TreeNode(-5)
root1.right = TreeNode(8)
root1.right.right = TreeNode(10)
root1.right.left = TreeNode(7)
root1.right.left.left = TreeNode(6)
a = Solution()
print(a.insert(root1,4)==root1.left.right)
# Out:
# True

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            new = TreeNode(val)
            new.left = root.left
            root.left = new
            #print("下面有節點的情況下，將相同的節點加到左邊")
            return root.left
          
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                #print("新節點加到左邊")
                return root.left
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                #print("新節點加到右邊")
                return root.right
            else:
                return Solution().insert(root.right,val)       
  
    def replace(root,target): #要怎麼跟search取得找到的那個target，也就是當下的root所在位置
        
        if root.right == None and root.left != None: # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
            temp = root.left
            while temp.right != None:
                temp = temp.right
        
        # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
        elif root.left == None and root.right != None: 
            temp = root.right
            while temp.left != None:
                temp = temp.left
                
        elif root.left != None and root.right != None :
            temp = root.right
            while temp.left != None:
                temp = temp.left
        
        return temp
            
   
    def pre_order(self,root): # root-->left-->right

        if root == None:
            return False
        else:
            preorder.append(root.val)
            if root.left != None:
                Solution().pre_order(root.left)
            if root.right != None:
                Solution().pre_order(root.right)
        return preorder
            
    def delete(self,root,target):  
        p = None
        d = root 
        
        
        
        #先找到要刪除的那個node
        while target != d.val:
            if target <= d.val:
                p = d
                d = d.left
            if target > d.val:
                p = d
                d = d.right
                
#         print(p.val)
#         print(d.val)

        # case1:delete_node沒有任何小孩，直接將delete_node刪除
        if d.left == None and d.right == None:
            # case1-1:delete_node比parent小，將parent左小孩指向空
            if d.val < p.val:
                p.left = None
                print("case1-1")
            #case1-2:delete_node比parent大，將parent右小孩指向空
            elif d.val > p.val:
                p.right = None
                print("case1-2")

        #第一大類:BST中沒有重複值
        if d.left.val != target:
            # case2:delete_node 只有左邊的小孩，找左邊小孩中最大的來補
            if d.left != None and d.right == None:
                # case2-1:delete_node左小孩中最大的是delete_node.left，直接將parent與delete_node.left連結
                if d.left.right == None:
                    p.left = d.left
                    print("case2-1")
                # case2-2:delete_node.left有right child，找delete_node.left.right中最大來補
                elif d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    p.left = cur
                    cur.left = d.left
                    d = None
                    curp.right = None
                    print("case2-2")
            # case3:delete_node 只有右邊的小孩，找右邊小孩中最小的來補
            if d.left == None and d.right != None:
                # case3-1: delete_node右小孩中最小的是delete_node.right
                if d.right.left == None:
                    p.left = d.right
                    print("case3-1")
                # case3-2: delete_node.right有left child，找delete_node.right.left中最小來補
                elif d.right.left != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    d = None
                    curp.left = None
                    print("case3-2")
            # case4:delete_node 有右邊及左邊的小孩，找右邊小孩中最小的或左邊最大來補
            if d.left != None and d.right != None:
                # case4-1: delete_node只有一個左小孩及一個右小孩
                if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                    p.left = d.left
                    p.left.right = d.right
                    print("case4-1")
                # case4-2: delete_node的左右小孩皆有左右小孩
                if d.left.left != None and d.left.right != None and d.right.left != None and d.right.right != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    cur.left = d.left
                    d = None
                    curp.left = None
                    print("case4-2")
            # case5: delete_node為root，找左邊最大或右邊最小來補
            # case5-1: root沒有右小孩，且root.left沒有右小孩(最大的就是d.left)
            if d.right == None and d.left.right == None:
                new = d.left
                d = None
                print("case5-1")
                return new
            # case5-2: root沒有左小孩，且root.right沒有左小孩(最小的就是d.right)
            if d.left == None and d.right.left == None:
                new = d.right
                d = None
                print("case5-2")
                return new   
            # case5-3: root只有左右各一個小孩，找左或右小孩來補
            if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                new = d.left
                new.right = d.right
                d = None
                print("case5-3")
                return new
            # case5-4: d的左小孩只要有右小孩，找右小孩中最大的
            if d.left.right != None:
                curp = d.left
                cur = d.left.right
                while cur.right != None:
                    curp = cur
                    cur = cur.right
                cur.left = d.left
                cur.right = d.right
                d = None
                curp.right = None
                print("case5-4")
                return cur
        
            # case5-5: d的右小孩只要有左小孩，找左小孩中最小的
            if d.right.left != None:
                curp = d.right
                cur = d.right.left
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                cur.right = d.right
                cur.left = d.left
                d = None
                curp.left = None
                print("case5-5")
                return cur    
                
        #第二大類:BST中有重複值
        elif d.left.val == target and d.val != target:
            # case6-1:刪除值之下有小孩
            end = d.left
            while end.val == target and end.left != None:
                d = end
                end = end.left
            p.left = end
            print("case6-1")
    
            # case6-2:刪除值之下沒有任何child
            end = d.left
            while end.val == target:
                d = end
                end = end.left
            
            p.left = None
            print("case6-2")
            
        # case6-3: 刪除值為root，且root.right沒左小孩
        elif d.left.val == target and d.val == target:
            if d.right.left == None:
                end = d.left
                new = d.right
                while end.val == target and end.left != None:
                    d = end
                    end = end.left
                new.left = end
                print("case6-3")
                return new
            # case6-4: 刪除值為root，且root.right有左小孩
            elif d.right.left != None:
                curp = d.right
                
                cur = curp.left
                end = d.left
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                print(cur.val)
                while end.val == target and end.left != None:
                    d = end
                    end = end.left
                print(end.val)  
                cur.right = d.right
                cur.left = end
                curp.left = None
                
                print("case6-4")
                return cur
            
            
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
     
        if target  == root.val:
            return root.val 
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
#     def modify(self,root,target,new_val):

# %%
preorder = []
a = Solution()
root = TreeNode(10) #如此一來root就有val、left、right屬性

# %%
a.insert(root,8)
a.insert(root,7)
a.insert(root,6)
a.insert(root,5)
a.insert(root,5.5)
a.insert(root,6.5)
a.insert(root,6.4)
a.insert(root,6.7)
a.insert(root,6.75)
a.delete(root,7)
a.pre_order(root)
# Out:
# case2-2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-bad6f2318c27> in <module>
#       8 a.insert(root,6.7)
#       9 a.insert(root,6.75)
# ---> 10 a.delete(root,7)
#      11 a.pre_order(root)
#
# <ipython-input-59-9afba0fb92a2> in delete(self, root, target)
#     114                     print("case2-2")
#     115             # case3:delete_node 只有右邊的小孩，找右邊小孩中最小的來補
# --> 116             if d.left == None and d.right != None:
#     117                 # case3-1: delete_node右小孩中最小的是delete_node.right
#     118                 if d.right.left == None:
#
# AttributeError: 'NoneType' object has no attribute 'left'

# %% [markdown]
# 11/16晚上隨便丟了一組測值，預計是要執行case2-2，但是執行完case2-2後也進入了其他case，代表各個情況間沒有劃分清楚，因此將不同條件間的判斷式改成if、elif、elif....

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            new = TreeNode(val)
            new.left = root.left
            root.left = new
            #print("下面有節點的情況下，將相同的節點加到左邊")
            return root.left
          
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                #print("新節點加到左邊")
                return root.left
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                #print("新節點加到右邊")
                return root.right
            else:
                return Solution().insert(root.right,val)       
  
    def replace(root,target): #要怎麼跟search取得找到的那個target，也就是當下的root所在位置
        
        if root.right == None and root.left != None: # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
            temp = root.left
            while temp.right != None:
                temp = temp.right
        
        # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
        elif root.left == None and root.right != None: 
            temp = root.right
            while temp.left != None:
                temp = temp.left
                
        elif root.left != None and root.right != None :
            temp = root.right
            while temp.left != None:
                temp = temp.left
        
        return temp
            
   
    def pre_order(self,root): # root-->left-->right

        if root == None:
            return False
        else:
            preorder.append(root.val)
            if root.left != None:
                Solution().pre_order(root.left)
            if root.right != None:
                Solution().pre_order(root.right)
        return preorder
            
    def delete(self,root,target):  
        p = None
        d = root 
        
        
        
        #先找到要刪除的那個node
        while target != d.val:
            if target <= d.val:
                p = d
                d = d.left
            if target > d.val:
                p = d
                d = d.right
                
#         print(p.val)
#         print(d.val)

        # case1:delete_node沒有任何小孩，直接將delete_node刪除
        if d.left == None and d.right == None:
            # case1-1:delete_node比parent小，將parent左小孩指向空
            if d.val < p.val:
                p.left = None
                print("case1-1")
            #case1-2:delete_node比parent大，將parent右小孩指向空
            elif d.val > p.val:
                p.right = None
                print("case1-2")

        #第一大類:BST中沒有重複值
        if d.left.val != target:
            # case2:delete_node 只有左邊的小孩，找左邊小孩中最大的來補
            if d.left != None and d.right == None:
                # case2-1:delete_node左小孩中最大的是delete_node.left，直接將parent與delete_node.left連結
                if d.left.right == None:
                    p.left = d.left
                    print("case2-1")
                # case2-2:delete_node.left有right child，找delete_node.left.right中最大來補
                elif d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    p.left = cur
                    cur.left = d.left
                    d = None
                    curp.right = None
                    print("case2-2")
            # case3:delete_node 只有右邊的小孩，找右邊小孩中最小的來補
            elif d.left == None and d.right != None:
                # case3-1: delete_node右小孩中最小的是delete_node.right
                if d.right.left == None:
                    p.left = d.right
                    print("case3-1")
                # case3-2: delete_node.right有left child，找delete_node.right.left中最小來補
                elif d.right.left != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    d = None
                    curp.left = None
                    print("case3-2")
            # case4:delete_node 有右邊及左邊的小孩，找右邊小孩中最小的或左邊最大來補
            elif d.left != None and d.right != None:
                # case4-1: delete_node只有一個左小孩及一個右小孩
                if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                    p.left = d.left
                    p.left.right = d.right
                    print("case4-1")
                # case4-2: delete_node的左右小孩皆有左右小孩
                if d.left.left != None and d.left.right != None and d.right.left != None and d.right.right != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    cur.left = d.left
                    d = None
                    curp.left = None
                    print("case4-2")
            # case5: delete_node為root，找左邊最大或右邊最小來補
            # case5-1: root沒有右小孩，且root.left沒有右小孩(最大的就是d.left)
            elif d.right == None and d.left.right == None:
                new = d.left
                d = None
                print("case5-1")
                return new
            # case5-2: root沒有左小孩，且root.right沒有左小孩(最小的就是d.right)
            elif d.left == None and d.right.left == None:
                new = d.right
                d = None
                print("case5-2")
                return new   
            # case5-3: root只有左右各一個小孩，找左或右小孩來補
            elif d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                new = d.left
                new.right = d.right
                d = None
                print("case5-3")
                return new
            # case5-4: d的左小孩只要有右小孩，找右小孩中最大的
            elif d.left.right != None:
                curp = d.left
                cur = d.left.right
                while cur.right != None:
                    curp = cur
                    cur = cur.right
                cur.left = d.left
                cur.right = d.right
                d = None
                curp.right = None
                print("case5-4")
                return cur
        
            # case5-5: d的右小孩只要有左小孩，找左小孩中最小的
            elif d.right.left != None:
                curp = d.right
                cur = d.right.left
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                cur.right = d.right
                cur.left = d.left
                d = None
                curp.left = None
                print("case5-5")
                return cur    
                
        #第二大類:BST中有重複值
        elif d.left.val == target and d.val != target:
            # case6-1:刪除值之下有小孩
            end = d.left
            while end.val == target and end.left != None:
                d = end
                end = end.left
            p.left = end
            print("case6-1")
    
            # case6-2:刪除值之下沒有任何child
            end = d.left
            while end.val == target:
                d = end
                end = end.left
            
            p.left = None
            print("case6-2")
            
        # case6-3: 刪除值為root，且root.right沒左小孩
        elif d.left.val == target and d.val == target:
            if d.right.left == None:
                end = d.left
                new = d.right
                while end.val == target and end.left != None:
                    d = end
                    end = end.left
                new.left = end
                print("case6-3")
                return new
            # case6-4: 刪除值為root，且root.right有左小孩
            elif d.right.left != None:
                curp = d.right
                
                cur = curp.left
                end = d.left
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                print(cur.val)
                while end.val == target and end.left != None:
                    d = end
                    end = end.left
                print(end.val)  
                cur.right = d.right
                cur.left = end
                curp.left = None
                
                print("case6-4")
                return cur
            
            
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
     
        if target  == root.val:
            return root.val 
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
#     def modify(self,root,target,new_val):

# %%
preorder = []
a = Solution()
root = TreeNode(10) #如此一來root就有val、left、right屬性

# %%
a.insert(root,12)
a.insert(root,13)
a.insert(root,11)
# a.insert(root,5)
# a.insert(root,5.5)
# a.insert(root,6.5)
# a.insert(root,6.4)
# a.insert(root,6.7)
# a.insert(root,6.75)
a.delete(root,10)
a.pre_order(root)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-2566bf1991c2> in <module>
#       8 # a.insert(root,6.7)
#       9 # a.insert(root,6.75)
# ---> 10 a.delete(root,10)
#      11 a.pre_order(root)
#
# <ipython-input-62-be8be5d75ace> in delete(self, root, target)
#      94
#      95         #第一大類:BST中沒有重複值
# ---> 96         if d.left.val != target:
#      97             # case2:delete_node 只有左邊的小孩，找左邊小孩中最大的來補
#      98             if d.left != None and d.right == None:
#
# AttributeError: 'NoneType' object has no attribute 'val'

# %%
class TreeNode():
    def __init__(self,val):
        self.val = val
        self.left = None
        self.right = None

class Solution(object):
    def insert(self,root,val):
        if val == root.val:
            new = TreeNode(val)
            new.left = root.left
            root.left = new
            #print("下面有節點的情況下，將相同的節點加到左邊")
            return root.left
          
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                #print("新節點加到左邊")
                return root.left
            else:
                return Solution().insert(root.left,val)
                
            
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                #print("新節點加到右邊")
                return root.right
            else:
                return Solution().insert(root.right,val)       
  
    def replace(root,target): #要怎麼跟search取得找到的那個target，也就是當下的root所在位置
        
        if root.right == None and root.left != None: # 找出替補的node(當target沒有right child時)，要找左邊當中最大的節點來補
            temp = root.left
            while temp.right != None:
                temp = temp.right
        
        # 找出替補的node(當target沒有left child或兩邊都有child時)，要找右邊當中最小的節點來補
        elif root.left == None and root.right != None: 
            temp = root.right
            while temp.left != None:
                temp = temp.left
                
        elif root.left != None and root.right != None :
            temp = root.right
            while temp.left != None:
                temp = temp.left
        
        return temp
            
   
    def pre_order(self,root): # root-->left-->right

        if root == None:
            return False
        else:
            preorder.append(root.val)
            if root.left != None:
                Solution().pre_order(root.left)
            if root.right != None:
                Solution().pre_order(root.right)
        return preorder
            
    def delete(self,root,target):  
        
        # case5: delete_node為root，找左邊最大或右邊最小來補
        if target == root.val:
            # case5-1: root只有left child，直接將root.left指定為新root
            if root.right == None and root.left != None:
                new = root.left
                root = None
                print("case5-1")
                return new
            # case5-2: root只有right child，直接將root.right指定為新的root
            elif root.left == None and root.right != None:
                new = root.right
                root = None
                print("case5-2")
                return new   
            # case5-3: root只有左右各一個小孩，找左或右小孩來補
            elif root.left.left == None and root.left.right == None and root.right.left == None and root.right.right == None:
                new = root.left
                new.right = root.right
                root = None
                print("case5-3")
                return new
            # case5-4: d的左小孩只要有右小孩，找右小孩中最大的
            elif root.left.right != None:
                curp = root.left
                cur = root.left.right
                while cur.right != None:
                    curp = cur
                    cur = cur.right
                cur.left = root.left
                cur.right = root.right
                root = None
                curp.right = None
                print("case5-4")
                return cur
        
                # case5-5: d的右小孩只要有左小孩，找左小孩中最小的
            elif root.right.left != None:
                curp = root.right
                cur = root.right.left
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                cur.right = root.right
                cur.left = root.left
                root = None
                curp.left = None
                print("case5-5")
                return cur 
           
        
        p = None
        d = root 
        
        
        #先找到要刪除的那個node
        while target != d.val:
            if target <= d.val:
                p = d
                d = d.left
            if target > d.val:
                p = d
                d = d.right
                
#         print(p.val)
#         print(d.val)

        # case1:delete_node沒有任何小孩，直接將delete_node刪除
        if d.left == None and d.right == None:
            # case1-1:delete_node比parent小，將parent左小孩指向空
            if d.val < p.val:
                p.left = None
                print("case1-1")
            #case1-2:delete_node比parent大，將parent右小孩指向空
            elif d.val > p.val:
                p.right = None
                print("case1-2")

        #第一大類:BST中沒有重複值
        elif d.left.val != target:
            # case2:delete_node 只有左邊的小孩，找左邊小孩中最大的來補
            if d.left != None and d.right == None:
                # case2-1:delete_node左小孩中最大的是delete_node.left，直接將parent與delete_node.left連結
                if d.left.right == None:
                    p.left = d.left
                    print("case2-1")
                # case2-2:delete_node.left有right child，找delete_node.left.right中最大來補
                elif d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    p.left = cur
                    cur.left = d.left
                    d = None
                    curp.right = None
                    print("case2-2")
            # case3:delete_node 只有右邊的小孩，找右邊小孩中最小的來補
            elif d.left == None and d.right != None:
                # case3-1: delete_node右小孩中最小的是delete_node.right
                if d.right.left == None:
                    p.left = d.right
                    print("case3-1")
                # case3-2: delete_node.right有left child，找delete_node.right.left中最小來補
                elif d.right.left != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    d = None
                    curp.left = None
                    print("case3-2")
            # case4:delete_node 有右邊及左邊的小孩，找右邊小孩中最小的或左邊最大來補
            elif d.left != None and d.right != None:
                # case4-1: delete_node只有一個左小孩及一個右小孩
                if d.left.left == None and d.left.right == None and d.right.left == None and d.right.right == None:
                    p.left = d.left
                    p.left.right = d.right
                    print("case4-1")
                # case4-2: delete_node的左右小孩皆有左右小孩
                if d.left.left != None and d.left.right != None and d.right.left != None and d.right.right != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    p.left = cur
                    cur.right = d.right
                    cur.left = d.left
                    d = None
                    curp.left = None
                    print("case4-2")



        #第二大類:BST中有重複值
        elif d.left.val == target and d.val != target:
            # case6-1:刪除值之下有小孩
            end = d.left
            while end.val == target and end.left != None:
                d = end
                end = end.left
            p.left = end
            print("case6-1")

            # case6-2:刪除值之下沒有任何child
            end = d.left
            while end.val == target:
                d = end
                end = end.left

            p.left = None
            print("case6-2")
            
    # case6-3: 刪除值為root，且root.right沒左小孩
#     elif d.left.val == target and d.val == target:
#         if d.right.left == None:
#             end = d.left
#             new = d.right
#             while end.val == target and end.left != None:
#                 d = end
#                 end = end.left
#             new.left = end
#             print("case6-3")
#             return new
#         # case6-4: 刪除值為root，且root.right有左小孩
#         elif d.right.left != None:
#             curp = d.right
                
#             cur = curp.left
#             end = d.left
#             while cur.left != None:
#                 curp = cur
#                 cur = cur.left
#             print(cur.val)
#             while end.val == target and end.left != None:
#                 d = end
#                 end = end.left
#             print(end.val)  
#             cur.right = d.right
#             cur.left = end
#             curp.left = None
                
#             print("case6-4")
#             return cur
            
            
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
     
        if target  == root.val:
            return root.val 
        
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
                
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
    def modify(self,root,target,new_val):
        Solution().delete(root,target)
        Solution().insert(root,new_val)

# %%
preorder = []
a = Solution()
root = TreeNode(9) #如此一來root就有val、left、right屬性

# %%
a.insert(root,8)
a.insert(root,7)
a.insert(root,8.5)
a.insert(root,10)
a.insert(root,9.5)
a.insert(root,11)
# a.insert(root,14.2)

# a.insert(root,14.1)
# a.insert(root,14.6)
# a.insert(root,14.8)
# a.insert(root,10.5)
# a.insert(root,11.3)
a.delete(root,11)
a.pre_order(root)
# Out:
# case1-2
# [9, 8, 7, 8.5, 10, 9.5]

# %%
class TreeNode(object):
    def __init__(self,x):
        self.val = x
        self.left = None
        self.right = None

class Solution(object):
    
    def insert(self,root,val):
        if val == root.val:
            new = TreeNode(val)
            new.left = root.left
            root.left = new
            #print("下面有節點的情況下，將相同的節點加到左邊")
            return root.left
        elif val < root.val: #跑到左邊
            if root.left == None:
                root.left = TreeNode(val)
                #print("新節點加到左邊")
                return root.left
            else:
                return Solution().insert(root.left,val)  
        elif val > root.val: #跑到右邊
            if root.right == None:
                root.right = TreeNode(val)
                #print("新節點加到右邊")
                return root.right
            else:
                return Solution().insert(root.right,val)    
   
    def pre(self,root,arr): # root-->left-->right
        
        if root == None:
            return arr
        arr.append(root.val)
        if root.left != None:
            Solution().pre(root.left,arr)
        if root.right != None:
            Solution().pre(root.right,arr)
        return arr
            
    def delete(self,root,target):  
        
        # case5: delete_node(不重複)為root，找左邊最大或右邊最小來補
        # case5-1: root只有right child
        if target == root.val and root.left == None and root.right != None:
            new = root.right
            root = None
            return new  

## case5-1測值:["10",12,11,10.5]
        
        elif target == root.val and root.left.val != target:
            # case5-2: root只有left child，直接將root.left指定為新root
            if root.right == None and root.left != None:
                new = root.left
                root = None
                return new
             
            # case5-3: root有左右小孩，找左或右小孩來補
            elif root.left.right == None and root.right.left == None:
                new = root.left
                new.right = root.right
                root = None
                return new
            # case5-4: d的左小孩只要有右小孩，找右小孩中最大的
            elif root.left.right != None:
                curp = root.left
                cur = root.left.right
                while cur.right != None:
                    curp = cur
                    cur = cur.right
                    
                curp.right = cur.left
                cur.right = root.right
                cur.left = root.left
                root = None
                return cur
        
            # case5-5: d的右小孩只要有左小孩，找左小孩中最小的
            elif root.right.left != None:
                curp = root.right
                cur = root.right.left
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                    
                cur.left = root.left
                curp.left = cur.right    
                cur.right = root.right
                root = None
                return cur
        
        # case7: 刪除值(重複)在root  
        elif target == root.val and root.left.val == target:
            if root.left != None and root.right != None:
                end = root.left
                r = root.right
                while end.val == target:
                    root = end
                    end = end.left
                root.right = r
                
                if root.left.right != None:
                    curp = root.left
                    cur = root.left.right
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    cur.right = root.right
                    cur.left = root.left
                    curp.right = None
                    return cur
## case7-1測值:["10","10","10",6,5,6.5,6.7,6.6,12,11,14]

                elif root.right.left != None:
                    curp = root.right
                    cur = root.right.left
                    while cur.left != None:
                        curp = cur 
                        cur = cur.left
                    cur.right = root.right
                    cur = left = root.left
                    curp.left = None
                    root = None
                    return cur
## case7-2測值:[""10","10","10",6,5,12,11,10.5,10.6,14"]

            # case7-3:root只有右小孩，直接將root.right指定為新root
            elif root.left == None and root.right != None:
                root = root.right
                return root
## case7-3測值:["10",20,19,21]

            # case7-4:root只有左小孩，直接將root.left指定為新root
            elif root.right == None and root.left != None :
                while root.left != None and root.left.val == target :
                    root = root.left
                if root.left == None:
                    return None
                else:
                    root = root.left
                    return root

        p = None
        d = root 
    
        #先找到要刪除的那個node
        while target != d.val:
            if target <= d.val:
                if d.left == None:
                    return root
                else:
                    p = d
                    d = d.left
            elif target > d.val:
                if d.right == None:
                    return root
                else:
                    p = d
                    d = d.right

        # case1:delete_node沒有任何小孩，直接將delete_node刪除
        if d.left == None and d.right == None:
            # case1-1:delete_node比parent小，將parent左小孩指向空
            if d.val < p.val:
                p.left = None
                return root
            #case1-2:delete_node比parent大，將parent右小孩指向空
            elif d.val > p.val:
                p.right = None
                return root
        
        # case3:delete_node 只有右邊的小孩(找右邊小孩中最小的來補)
        elif d.left == None and d.right != None:
            # case3-1: p.left = d，且d.left只有left child
            if p.left == d and d.right.left == None and d.right.right != None:
                p.left = d.right
                return root
## case3-1測值:[9,8,"7",7.1,7.2,7.3]

            # case3-2: p.left = d，且d.right只有left child
            elif p.left == d and d.right.right == None and d.right.left != None:
                cur = d.right.left
                curp = d.right
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                p.left = cur
                cur.right = d.right
                d = None
                curp.left = None
                return root
## case3-2測值:[9,8,"7",7.1,7.05,7.03,7.06,7.07]  

            # case3-3: p.left = d，且d.right有right child & left child
            elif p.left == d and d.right.left != None and d.right.right != None:
                cur = d.right.left
                curp = d.right
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                p.left = cur
                curp.left = cur.right
                cur.right = d.right
                d = None
                return root
## case3-3測值:[9,8,"7",7.1,7.05,7.03,7.06,7.07,7.2,7.3]

            # case3-4: p.right = d，且d.right只有right child
            elif p.right == d and d.right.left == None and d.right.right != None:
                p.right = d.right
                return root
## case3-4測值:[9,10,"20",22,24]

            # case3-5: p.right = d，且d.right只有left child
            elif p.right == d and d.right.right == None and d.right.left != None:
                cur = d.right.left
                curp = d.right
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                p.right = cur
                cur.right = d.right
                d = None
                curp.left = None
                return root
## case3-5測值:[9,10,"20",22,21.5,21,21.6,21.7] 

            # case3-6: p.right = d，且d.right有right child & left child
            elif p.right == d and d.right.left != None and d.right.right != None:
                cur = d.right.left
                curp = d.right
                while cur.left != None:
                    curp = cur
                    cur = cur.left
                p.right = cur
                curp.left = cur.right
                cur.right = d.right
                d = None
                return root
## case3-6測值:[9,10,"20",22,21.5,21,21.6,21.7,24] 

        #第一大類:BST中沒有重複值
        elif root.val != target:
            
            # case2:delete_node 只有左邊的小孩(找左邊小孩中最大的來補)
            if d.left != None and d.right == None:
                # case2-1: p.left = d，且d.left只有left child
                if p.left == d and d.left.right == None and d.left.left != None:
                    p.left = d.left
                    return root
## case2-1測值:[9,8,"7",6,5]
                    
                # case2-2: p.left = d，且d.left只有right child
                elif p.left == d and d.left.left == None and d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    p.left = cur
                    cur.left = d.left
                    d = None
                    curp.right = None
                    return root
## case2-2測值:[9,8,"7",6,6.5,6.4,6.3,6.45,6.8]
                    
                # case2-3: p.left = d，且d.left有right child & left child
                elif p.left == d and d.left.left != None and d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    p.left = cur
                    curp.right = cur.left
                    cur.left = d.left
                    d = None
                    return root
## case2-3測值:[9,8,"7",6,5,6.5,6.4,6.3,6.45,6.8]
                
                # case2-4: p.right = d，且d.left只有left child
                elif p.right == d and d.left.right == None and d.left.left != None:
                    p.right = d.left
                    return root
## case2-4測值:[9,10,"11",10.5,10.4]

                # case2-5: p.right = d，且d.left只有right child
                elif p.right == d and d.left.left == None and d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    p.right = cur
                    cur.left = d.left
                    d = None
                    curp.right = None
                    return root
## case2-5測值:[9,10,"11",10.5,10.55,10.54,10.53,10.56,10.65]

                # case2-6: p.right = d，且d.left有right child & left child
                elif p.right == d and d.left.left != None and d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    p.right = cur
                    curp.right = cur.left
                    cur.left = d.left
                    d = None
                    return root
## case2-6測值:[9,10,"11",10.5,10.4,10.55,10.54,10.53,10.56,10.65]

            # case4:delete_node 有左右兩邊的小孩(找左邊小孩中最大或右邊最小的來補) 
            elif d.left != None and d.right != None:
                # case4-1:找左邊最大
                if p.right == d and d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    
                    p.right = cur
                    curp.right = cur.left
                    cur.left = d.left
                    cur.right = d.right
                    d = None
                    return root
                # case4-1:找右邊最小
                elif p.right == d and d.right.left != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    
                    p.right = cur
                    curp.left = cur.right
                    cur.right = d.right
                    cur.left = d.left
                    d = None
                    return root
## case4-1測值:[9,10,"11",10.5,10.4,10.55,10.65,22,21,5,21,24]
                # case4-2:找左邊最大
                elif p.left == d and d.left.right != None:
                    cur = d.left.right
                    curp = d.left
                    while cur.right != None:
                        curp = cur
                        cur = cur.right
                    
                    p.left = cur
                    curp.right = cur.left
                    cur.left = d.left
                    cur.right = d.right
                    d = None
                    return root
                # case4-2:找右邊最小
                elif p.left == d and d.right.left != None:
                    cur = d.right.left
                    curp = d.right
                    while cur.left != None:
                        curp = cur
                        cur = cur.left
                    
                    p.left = cur
                    curp.left = cur.right
                    cur.right = d.right
                    cur.left = d.left
                    d = None
                    return root
## case4-2測值:[9,8,"7",6,5,5.5,6.5,6.4,6.7,6.75,7.1,7.05,7.03,7.2]
                # case4-3:d.left.right為空且d.right.left為空
                elif d.left.right == None and d.right.left == None:
                    if p.left != None and p.left == d:
                        p.left = d.left
                    else:
                        p.right = d.left
                    d.left.right = d.right
                    d = None
                    return root
        #第二大類:BST中有重複值
        
        elif d.left.val == target:
            # case6-1: 刪除值不在root且p.left = d
            if p.left == d:
                end = d.left
                while end.val == target:
                    d = end
                    end = end.left
                end.right = p.left.right
                p.left = end
                return root
## case6-1測值:[10,"6",6.5,"6","6",5,12]

            # case6-2: 刪除值不在root且p.righ = d
            elif p.right == d:
                end = d.left
                while end.val == target:
                    d = end
                    end = end.left
                end.right = p.right.right
                p.right = end
                return root
##case6-2測值:[10,"12",13,"12","12",11]
  
    def search(self,root,target): #因為助教要的是離root最近的target，因此只要找到第一個target就可以return 
        if target  == root.val:
            return root
        elif target < root.val :
            if root.left == None:
                return False
            else:
                return Solution().search(root.left,target)
        elif target > root.val:
            if root.right == None:
                return False
            else:
                return Solution().search(root.right,target)
            
    def modify(self,root,target,new_val):
        if target != new_val: #先新增再刪除相較之下是較適當且較快速的方式
            Solution().insert(root,new_val)
            return Solution().delete(root,target)
        else: #當修改前後的值相同，直接用修改前的tree做preorder
            return root

# %%
root = TreeNode(10)
a = Solution()
a.insert(root,8)
a.insert(root,6)
a.insert(root,9)
a.insert(root,5)
a.insert(root,7)
a.insert(root,8.5)
a.insert(root,9.5)
a.insert(root,6.5)
# a.insert(root,7.1)
# a.insert(root,7.05)
a.delete(root,8)
a.pre(root,[])
# Out:
# [10, 7, 6, 5, 6.5, 9, 8.5, 9.5]

# %% [markdown]
# 測試modify是否正確:
#
# 修改有兩種方式，一個是先刪除後新增，另一種是先新增後刪除，但當遇到修改的值一樣(也就是假設你要將10修改為10)，此時如果先新增再刪除，實際上的結果會是兩個10都被刪除，在使用者的角度上並不符合使用者的需求，換個角度想，其實當遇到修改的值與原先的相同時，他們的架構是不變的，因此可以直接用修改前的BST來preorder
#
# 若是修改值與原先值不同，那麼先刪除後新增雖然仍是符合BST規則，但你並不能確保節點順序不改變，因此先新增再刪除會是較適當的做法

# %% [markdown]
# 最後再丟一組測值試試看答案是否正確

# %%
root = TreeNode(10)
a = Solution()
a.insert(root,5)
a.insert(root,4)
a.insert(root,15)
a.insert(root,14)
a.insert(root,16)
a.insert(root,6)
a.insert(root,5.5)
# a.insert(root,7)
# a.insert(root,6.5)
# a.insert(root,11.55)
a.pre(a.delete(root,10),[])
# Out:
# [6, 5, 4, 5.5, 15, 14, 16]

# %% [markdown]
# 流程圖:

# %%
from IPython.display import Image
from IPython.core.display import HTML
Image(url="https://github.com/imucici/my-learning-note/blob/master/%E5%9C%96%E7%89%87/BST%20case1%E3%80%812.jpg?raw=true"  ,width = 1000,height = 1000)
# Out:
# <img src="https://github.com/imucici/my-learning-note/blob/master/%E5%9C%96%E7%89%87/BST%20case1%E3%80%812.jpg?raw=true" width="1000" height="1000"/>

# %%
from IPython.display import Image
from IPython.core.display import HTML
Image(url="https://github.com/imucici/my-learning-note/blob/master/%E5%9C%96%E7%89%87/BST%20case3.jpg?raw=true"  ,width = 1000,height = 1000)
# Out:
# <img src="https://github.com/imucici/my-learning-note/blob/master/%E5%9C%96%E7%89%87/BST%20case3.jpg?raw=true" width="1000" height="1000"/>

# %%
from IPython.display import Image
from IPython.core.display import HTML
Image(url="https://github.com/imucici/my-learning-note/blob/master/%E5%9C%96%E7%89%87/BST%20case4%E3%80%815.jpg?raw=true"  ,width = 1000,height = 1000)
# Out:
# <img src="https://github.com/imucici/my-learning-note/blob/master/%E5%9C%96%E7%89%87/BST%20case4%E3%80%815.jpg?raw=true" width="1000" height="1000"/>

# %%
from IPython.display import Image
from IPython.core.display import HTML
Image(url="https://github.com/imucici/my-learning-note/blob/master/%E5%9C%96%E7%89%87/BST%20case6%E3%80%817.jpg?raw=true"  ,width = 1000,height = 1000)
# Out:
# <img src="https://github.com/imucici/my-learning-note/blob/master/%E5%9C%96%E7%89%87/BST%20case6%E3%80%817.jpg?raw=true" width="1000" height="1000"/>

# %% [markdown]
# 總結:
#
# 在寫BST的過程中，最常遇到的error就是遞迴深度錯誤，這種情況就是發生在我寫while來尋找delete後的那個替補節點時，不是指到None時還繼續往下遞迴，就是條件設錯或設的不嚴謹，導致報錯。
#
#
# 另外我很常會出現"xxx" object has no attribute 'val'，像是
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-a71321af42d0> in <module>
#       4 a.insert(root,5)
#       5 a.insert(root,3)
# ----> 6 a.pre_order(a.delete(root,9))
#
# <ipython-input-43-eeada734e18c> in delete(self, root, target)
#      76         if d.right == None and d.left.right == None:
#      77             d = None
# ---> 78             d = d.left
#      79             return d
#      80
#
# AttributeError: 'NoneType' object has no attribute 'left'
#
# >這種狀況就是你已經先跟程式講說d指定為空，之後卻要他執行d.left，他當然不會有val、left、right這些屬性

# %% [markdown]
# 心得:
#
# 終於把程式寫完時，只是覺得程式碼很長很長，寫到好累，但沒有意識到會寫到400多行，放上github的那一霎那真的有嚇到，不過確實很有成就感，第一次寫出破百行的程式。過程中出現無數次的error，幾乎都是相同的error一再重複出現，雖然一開始完全不知道error到底在說啥，或為什麼會報錯，但越寫越多以及跟同學一起討論，到後期真的有感覺到自己慢慢進入狀況，看到error也能經過思考後成功debug。這段時間裡其實也寫到很崩潰，尤其是delete的部分，第一次寫完總覺得應該都把所有case都考慮到了吧，沒想到只是隨便丟一兩組測值，就不斷報錯，改到後來甚至會連原本沒錯的case都error，在思緒完全被打亂的狀況下，我直接下定決心砍掉重練，把所有case再仔細想過，每個條件都設的很嚴謹，讓程式碼能順利進入條件，也能成功跳出迴圈。
#
# 在和同學討論的過程中，也發現自己有些觀念、邏輯並未全通，有時也很佩服那些邏輯很清楚的同學是如何一看到error就知道問題出在哪，他們背後的付出及努力也很直接反應出來。希望自己在寫程式的過程中能慢慢訓練自己debug的能力，讓自學功效發揮到最大!
